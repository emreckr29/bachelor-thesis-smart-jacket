# %%
pip install numpy pandas scikit-learn tensorflow matplotlib seaborn pyquaternion
# Out:
# Collecting numpy
#   Using cached numpy-2.3.4-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting pandas
#   Using cached pandas-2.3.3-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.2-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting tensorflow
#   Using cached tensorflow-2.20.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.10.7-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyquaternion
#   Using cached pyquaternion-0.9.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/python313/lib/python3.1/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Using cached flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /opt/conda/envs/python313/lib/python3.1/site-packages (from tensorflow) (25.0)
# Collecting protobuf>=5.28.0 (from tensorflow)
#   Using cached protobuf-6.33.0-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting requests<3,>=2.21.0 (from tensorflow)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting setuptools (from tensorflow)
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/envs/python313/lib/python3.1/site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Using cached termcolor-3.2.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in /opt/conda/envs/python313/lib/python3.1/site-packages (from tensorflow) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-2.0.1-cp313-cp313-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (9.0 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Using cached grpcio-1.76.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.7 kB)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Using cached tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.10.0 (from tensorflow)
#   Downloading keras-3.12.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Using cached h5py-3.15.1-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Using cached ml_dtypes-0.5.3-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.21.0->tensorflow)
#   Using cached charset_normalizer-3.4.4-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorflow)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorflow)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorflow)
#   Using cached certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting markdown>=2.6.8 (from tensorboard~=2.20.0->tensorflow)
#   Downloading markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Collecting pillow (from tensorboard~=2.20.0->tensorflow)
#   Using cached pillow-12.0.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow)
#   Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.20.0->tensorflow)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.60.1-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (112 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from keras>=3.10.0->tensorflow)
#   Using cached rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.10.0->tensorflow)
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.10.0->tensorflow)
#   Using cached optree-0.17.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (33 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow)
#   Using cached markupsafe-3.0.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.10.0->tensorflow)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/envs/python313/lib/python3.1/site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached numpy-2.3.4-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Using cached pandas-2.3.3-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.3 MB)
# Using cached scikit_learn-1.7.2-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.4 MB)
# Using cached tensorflow-2.20.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (620.8 MB)
# Using cached grpcio-1.76.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.6 MB)
# Using cached ml_dtypes-0.5.3-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (4.9 MB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached matplotlib-3.10.7-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached pyquaternion-0.9.9-py3-none-any.whl (14 kB)
# Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Using cached certifi-2025.10.5-py3-none-any.whl (163 kB)
# Using cached contourpy-1.3.3-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Using cached fonttools-4.60.1-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (4.9 MB)
# Using cached gast-0.6.0-py3-none-any.whl (21 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached h5py-3.15.1-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.1 MB)
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading keras-3.12.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 24.3 MB/s  0:00:00
# Using cached kiwisolver-1.4.9-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
# Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
# Downloading markdown-3.10-py3-none-any.whl (107 kB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached pillow-12.0.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
# Using cached protobuf-6.33.0-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading scipy-1.16.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 80.2 MB/s  0:00:006m0:00:0100:01
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Using cached termcolor-3.2.0-py3-none-any.whl (7.7 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Using cached markupsafe-3.0.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Downloading wrapt-2.0.1-cp313-cp313-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (121 kB)
# Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Using cached optree-0.17.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (414 kB)
# Using cached rich-14.2.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: pytz, namex, libclang, flatbuffers, wrapt, wheel, urllib3, tzdata, threadpoolctl, termcolor, tensorboard-data-server, setuptools, pyparsing, protobuf, pillow, optree, opt_einsum, numpy, mdurl, MarkupSafe, markdown, kiwisolver, joblib, idna, grpcio, google_pasta, gast, fonttools, cycler, charset_normalizer, certifi, absl-py, werkzeug, scipy, requests, pyquaternion, pandas, ml_dtypes, markdown-it-py, h5py, contourpy, astunparse, tensorboard, scikit-learn, rich, matplotlib, seaborn, keras, tensorflow
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49/49 [tensorflow]nsorflow]ras]n]ib]n]ata-server]
# Successfully installed MarkupSafe-3.0.3 absl-py-2.3.1 astunparse-1.6.3 certifi-2025.10.5 charset_normalizer-3.4.4 contourpy-1.3.3 cycler-0.12.1 flatbuffers-25.9.23 fonttools-4.60.1 gast-0.6.0 google_pasta-0.2.0 grpcio-1.76.0 h5py-3.15.1 idna-3.11 joblib-1.5.2 keras-3.12.0 kiwisolver-1.4.9 libclang-18.1.1 markdown-3.10 markdown-it-py-4.0.0 matplotlib-3.10.7 mdurl-0.1.2 ml_dtypes-0.5.3 namex-0.1.0 numpy-2.3.4 opt_einsum-3.4.0 optree-0.17.0 pandas-2.3.3 pillow-12.0.0 protobuf-6.33.0 pyparsing-3.2.5 pyquaternion-0.9.9 pytz-2025.2 requests-2.32.5 rich-14.2.0 scikit-learn-1.7.2 scipy-1.16.3 seaborn-0.13.2 setuptools-80.9.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.2.0 threadpoolctl-3.6.0 tzdata-2025.2 urllib3-2.5.0 werkzeug-3.1.3 wheel-0.45.1 wrapt-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Adım 1: Gerekli Kütüphaneleri Yükleme
import os
import numpy as np
import pickle
from pyquaternion import Quaternion # Normalizasyon için
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# --- KONFİGÜRASYON ---
# Verinin bulunduğu ana klasör
DATA_FOLDER = '' 
# Hangi hareketi eğitmek istiyoruz?
MOVEMENT_TYPE = ''
# Tüm zaman serilerini eşitleyeceğimiz uzunluk (gördüğümüz 80-82'ye göre 80 ideal)
TIMESTEPS = 80
NUM_SENSORS = 10
FEATURES_PER_SENSOR = 4 # w, x, y, z
FEATURES = NUM_SENSORS * FEATURES_PER_SENSOR # Toplam 40 özellik
USERS_TO_ANALYZE = ["User-A","User-B","User-C", "User-D", "User-E"]


# --- Adım 2.1: Normalizasyon için Yardımcı Fonksiyon ---

def normalize_sequence(sequence_data):
    """
    (N, 40) şeklindeki bir NumPy dizisini ilk karesine göre normalize eder.
    Sıralamanın (w, x, y, z) olduğunu varsayar.
    """
    if not sequence_data.any(): # Tamamen sıfırsa dokunma
        return sequence_data
    
    # 1. İlk kareyi (referans yönelimi) al
    first_frame = sequence_data[0] # (40,) şeklinde
    inverse_references = []
    
    # 2. 10 sensör için de ters (inverse) quaternion'ları hesapla
    for i in range(NUM_SENSORS):
        offset = i * FEATURES_PER_SENSOR
        w, x, y, z = first_frame[offset], first_frame[offset+1], first_frame[offset+2], first_frame[offset+3]
        
        # Olası bir sıfır veriye karşı koruma
        if w == 0 and x == 0 and y == 0 and z == 0:
             q_ref = Quaternion(1, 0, 0, 0) # Nötr (identity) quaternion
        else:
            q_ref = Quaternion(w, x, y, z)
            
        inverse_references.append(q_ref.inverse)
        
    normalized_sequence = []
    
    # 3. Tüm zaman adımlarını (timesteps) bu referanslara göre normalize et
    for frame in sequence_data:
        normalized_frame_features = []
        for i in range(NUM_SENSORS):
            offset = i * FEATURES_PER_SENSOR
            w, x, y, z = frame[offset], frame[offset+1], frame[offset+2], frame[offset+3]
            
            if w == 0 and x == 0 and y == 0 and z == 0:
                q_live = Quaternion(1, 0, 0, 0)
            else:
                q_live = Quaternion(w, x, y, z)
            
            # Referans yönelimi çıkar
            q_normalized = inverse_references[i] * q_live
            
            # Yeni (w,x,y,z) değerlerini düz listeye ekle
            normalized_frame_features.extend([q_normalized.w, q_normalized.x, q_normalized.y, q_normalized.z])
        
        normalized_sequence.append(normalized_frame_features)
        
    return np.array(normalized_sequence)


# --- Adım 2: Veriyi Yükleme ve Ön İşleme ---
print("Adım 2: Veri Yükleme ve Ön İşleme Başladı...")

all_data = []
all_labels = []

movement_path = os.path.join(DATA_FOLDER, MOVEMENT_TYPE)
# User-A, User-B, ... klasörlerinde gezin
for user_folder in USERS_TO_ANALYZE:
    user_path = os.path.join(movement_path, user_folder)
    if os.path.isdir(user_path) and user_folder.startswith('User-'):

        # True, WrongElbow, ... klasörlerinde gezin
        for label_folder in os.listdir(user_path):
            label_path = os.path.join(user_path, label_folder)
            if os.path.isdir(label_path):

                # .pkl dosyalarını oku
                for pkl_file in os.listdir(label_path):
                    if pkl_file.endswith('.pkl'):
                        file_path = os.path.join(label_path, pkl_file)

                        try:
                            with open(file_path, 'rb') as f:
                                obj = pickle.load(f)

                            # .pkl içindeki 'data' anahtarından veriyi al
                            recording_data = np.array(obj['data'])

                            # Veri geçerli mi diye kontrol et (en az 1 frame olmalı)
                            if recording_data.shape[0] < 1 or recording_data.shape[1] != FEATURES:
                                print(f"Uyarı: Hatalı veri atlanıyor (şekil {recording_data.shape}): {file_path}")
                                continue

                            # --- YENİ: Normalizasyon ---
                            recording_data_normalized = normalize_sequence(recording_data)

                            all_data.append(recording_data_normalized)
                            all_labels.append(label_folder) # Etiket olarak klasör adını kullan

                        except Exception as e:
                            print(f"Hata: {file_path} dosyası okunurken hata oluştu: {e}")

print(f"Toplam {len(all_data)} adet .pkl kaydı yüklendi.")

# --- Adım 3: Boyut Eşitleme (Padding/Trimming) ---
print(f"Adım 3: Tüm veriler {TIMESTEPS} adımına eşitleniyor...")

# Keras'ın 'pad_sequences' fonksiyonunu kullanalım. Çok daha verimli.
# 'post' = eksik veriyi sona ekle/sondan kırp
X_padded = pad_sequences(
    all_data, 
    maxlen=TIMESTEPS, 
    dtype='float32', 
    padding='post', 
    truncating='post'
)

print("Boyut Eşitleme Tamamlandı.\n")


# --- Adım 4: Veriyi Derin Öğrenme Formatına Dönüştürme ---
print("Adım 4: Veriyi Derin Öğrenme Formatına Dönüştürme Başladı...")

X = X_padded # Artık tüm verilerimiz (sample_sayısı, 80, 40) şeklinde
y = np.array(all_labels)

# Etiketleri sayısal değerlere çevir (örn: 'Correct' -> 0, 'WrongElbow' -> 1)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Sınıf sayısını al
num_classes = len(label_encoder.classes_)
print(f"Bulunan sınıflar ({num_classes} adet): {label_encoder.classes_}")

# Sayısal etiketleri one-hot encoding formatına çevir
# Örn: 3 sınıf varsa, 1 -> [0, 1, 0]
y_one_hot = to_categorical(y_encoded, num_classes=num_classes)

print(f"Veri şekli (X): {X.shape}")
print(f"Etiket şekli (y): {y_one_hot.shape}")
print("Veri Dönüştürme Tamamlandı.\n")


# --- Adım 5: Eğitim ve Test Verisi Olarak Ayırma ve Ölçekleme ---
print("Adım 5: Veriyi Ayırma ve Ölçekleme Başladı...")

X_train, X_test, y_train, y_test = train_test_split(
    X, y_one_hot, 
    test_size=0.2,       # Verinin %20'sini test için ayır
    random_state=42,     # Tekrarlanabilir sonuçlar için
    stratify=y_one_hot   # Sınıf dağılımını koru (çok önemli)
)

# Ölçekleme (Scaling) için veriyi 2D'ye çevirmemiz gerekiyor
# (sample_sayısı, 80, 40) -> (sample_sayısı * 80, 40)
scaler = StandardScaler()
X_train_reshaped = X_train.reshape(-1, FEATURES)
scaler.fit(X_train_reshaped)

X_train_scaled_reshaped = scaler.transform(X_train_reshaped)
X_test_scaled_reshaped = scaler.transform(X_test.reshape(-1, FEATURES))

# Veriyi tekrar 3D (LSTM formatı) haline getirelim
X_train_scaled = X_train_scaled_reshaped.reshape(X_train.shape)
X_test_scaled = X_test_scaled_reshaped.reshape(X_test.shape)

print(f"Eğitim verisi: {X_train_scaled.shape}, Test verisi: {X_test_scaled.shape}")
print("Veri Ayırma ve Ölçekleme Tamamlandı.\n")


# --- Adım 6: LSTM Modelini Oluşturma ---
print("Adım 6: LSTM Modeli Oluşturuluyor...")

model = Sequential([
    # Input katmanı: (80, 40) şeklinde veri alacak
    LSTM(64, input_shape=(TIMESTEPS, FEATURES), return_sequences=True),
    BatchNormalization(), # Katmanlar arası normalizasyon, öğrenmeyi hızlandırır
    Dropout(0.3),
    
    LSTM(32, return_sequences=False), # Son LSTM katmanı, sadece son çıktıyı verir
    BatchNormalization(),
    Dropout(0.3),
    
    Dense(32, activation='relu'),
    
    # Çıkış katmanı: Sınıf sayısı kadar nöron ve 'softmax' aktivasyonu
    Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
print("Model Oluşturma Tamamlandı.\n")


# --- Adım 7: Modeli Eğitme ---
print("Adım 7: Model Eğitimi Başlıyor...")

history = model.fit(
    X_train_scaled, 
    y_train, 
    epochs=60, # Epoch sayısını 50-100 arası deneyebilirsin
    batch_size=16, 
    validation_data=(X_test_scaled, y_test)
)

print("Model Eğitimi Tamamlandı.\n")


# --- Adım 8: Modeli Değerlendirme ---
print("Adım 8: Model Değerlendirmesi...")

# Test verisi üzerindeki loss ve accuracy değerleri
loss, accuracy = model.evaluate(X_test_scaled, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")

# Tahminleri yap
y_pred_probs = model.predict(X_test_scaled)
y_pred = np.argmax(y_pred_probs, axis=1) # Olasılıklardan en yüksek sınıfı seç
y_test_labels = np.argmax(y_test, axis=1) # One-hot'tan normal etikete dön

# Sınıflandırma Raporu (Precision, Recall, F1-score)
print("\nClassification Report:")
print(classification_report(y_test_labels, y_pred, target_names=label_encoder.classes_))

# Karışıklık Matrisi (Confusion Matrix)
print("\nConfusion Matrix:")
cm = confusion_matrix(y_test_labels, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='Blues', 
    xticklabels=label_encoder.classes_, 
    yticklabels=label_encoder.classes_
)
plt.xlabel('Tahmin Edilen (Predicted)')
plt.ylabel('Gerçek (True)')
plt.show()


# --- Adım 9: Modeli ve Gerekli Nesneleri Kaydetme ---
print("\nAdım 9: Model ve diğer nesneler kaydediliyor...")

MODEL_OUTPUT_DIR = f"final_lstm_models_{MOVEMENT_TYPE}"
if not os.path.exists(MODEL_OUTPUT_DIR):
    os.makedirs(MODEL_OUTPUT_DIR)

# 1. Keras modelini kaydet
model.save(os.path.join(MODEL_OUTPUT_DIR, f'{MOVEMENT_TYPE}_lstm_model.h5'))

# 2. Scaler'ı kaydet
with open(os.path.join(MODEL_OUTPUT_DIR, f'{MOVEMENT_TYPE}_scaler.pkl'), 'wb') as f:
    pickle.dump(scaler, f)

# 3. Label Encoder'ı kaydet
with open(os.path.join(MODEL_OUTPUT_DIR, f'{MOVEMENT_TYPE}_label_encoder.pkl'), 'wb') as f:
    pickle.dump(label_encoder, f)

print(f"Tüm dosyalar başarıyla '{MODEL_OUTPUT_DIR}' klasörüne kaydedildi.")
# Out:
# 2025-11-10 01:59:57.883238: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-10 01:59:57.883621: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-10 01:59:57.948851: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-10 01:59:59.250777: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-10 01:59:59.252345: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# Adım 2: Veri Yükleme ve Ön İşleme Başladı...
# Toplam 300 adet .pkl kaydı yüklendi.
# Adım 3: Tüm veriler 80 adımına eşitleniyor...
# Boyut Eşitleme Tamamlandı.
#
# Adım 4: Veriyi Derin Öğrenme Formatına Dönüştürme Başladı...
# Bulunan sınıflar (4 adet): ['LeaningOppositeSide' 'TooHighAbduction' 'True' 'WrongElbow']
# Veri şekli (X): (300, 80, 40)
# Etiket şekli (y): (300, 4)
# Veri Dönüştürme Tamamlandı.
#
# Adım 5: Veriyi Ayırma ve Ölçekleme Başladı...
# Eğitim verisi: (240, 80, 40), Test verisi: (60, 80, 40)
# Veri Ayırma ve Ölçekleme Tamamlandı.
#
# Adım 6: LSTM Modeli Oluşturuluyor...
# 2025-11-10 02:00:03.309774: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /opt/conda/envs/python313/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 80, 64)         │        26,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 80, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 80, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,868 (159.64 KB)
#  Trainable params: 40,676 (158.89 KB)
#  Non-trainable params: 192 (768.00 B)
# Model Oluşturma Tamamlandı.
#
# Adım 7: Model Eğitimi Başlıyor...
# Epoch 1/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.3875 - loss: 1.4553 - val_accuracy: 0.5333 - val_loss: 1.3074
# Epoch 2/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5167 - loss: 1.1318 - val_accuracy: 0.6167 - val_loss: 1.2424
# Epoch 3/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6917 - loss: 0.8698 - val_accuracy: 0.6167 - val_loss: 1.1690
# Epoch 4/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.7458 - loss: 0.7388 - val_accuracy: 0.6167 - val_loss: 1.0732
# Epoch 5/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8083 - loss: 0.5841 - val_accuracy: 0.7167 - val_loss: 0.9438
# Epoch 6/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8542 - loss: 0.4344 - val_accuracy: 0.7833 - val_loss: 0.8130
# Epoch 7/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8958 - loss: 0.3434 - val_accuracy: 0.8500 - val_loss: 0.6592
# Epoch 8/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9417 - loss: 0.2644 - val_accuracy: 0.8833 - val_loss: 0.5411
# Epoch 9/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9417 - loss: 0.1920 - val_accuracy: 0.8667 - val_loss: 0.4660
# Epoch 10/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9833 - loss: 0.1340 - val_accuracy: 0.8833 - val_loss: 0.4093
# Epoch 11/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9833 - loss: 0.1159 - val_accuracy: 0.9000 - val_loss: 0.3705
# Epoch 12/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9917 - loss: 0.0778 - val_accuracy: 0.9000 - val_loss: 0.3474
# Epoch 13/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9833 - loss: 0.0679 - val_accuracy: 0.9000 - val_loss: 0.3606
# Epoch 14/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0519 - val_accuracy: 0.9167 - val_loss: 0.3595
# Epoch 15/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9958 - loss: 0.0401 - val_accuracy: 0.9333 - val_loss: 0.3674
# Epoch 16/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9917 - loss: 0.0505 - val_accuracy: 0.9333 - val_loss: 0.3430
# Epoch 17/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9917 - loss: 0.0466 - val_accuracy: 0.9500 - val_loss: 0.3559
# Epoch 18/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0204 - val_accuracy: 0.9333 - val_loss: 0.3754
# Epoch 19/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0227 - val_accuracy: 0.9333 - val_loss: 0.4248
# Epoch 20/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9958 - loss: 0.0187 - val_accuracy: 0.9333 - val_loss: 0.3829
# Epoch 21/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 0.9333 - val_loss: 0.3767
# Epoch 22/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 0.9500 - val_loss: 0.3818
# Epoch 23/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0159 - val_accuracy: 0.9333 - val_loss: 0.3986
# Epoch 24/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.9500 - val_loss: 0.4060
# Epoch 25/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.9500 - val_loss: 0.4085
# Epoch 26/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 0.9500 - val_loss: 0.4143
# Epoch 27/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.9500 - val_loss: 0.4190
# Epoch 28/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.9500 - val_loss: 0.4174
# Epoch 29/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.9500 - val_loss: 0.4136
# Epoch 30/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.9500 - val_loss: 0.4145
# Epoch 31/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.9500 - val_loss: 0.4322
# Epoch 32/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9500 - val_loss: 0.4359
# Epoch 33/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9500 - val_loss: 0.4352
# Epoch 34/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9500 - val_loss: 0.4386
# Epoch 35/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.9500 - val_loss: 0.4436
# Epoch 36/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.9500 - val_loss: 0.4586
# Epoch 37/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.9500 - val_loss: 0.4665
# Epoch 38/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.9500 - val_loss: 0.4704
# Epoch 39/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9500 - val_loss: 0.4692
# Epoch 40/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9500 - val_loss: 0.4685
# Epoch 41/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.9500 - val_loss: 0.4718
# Epoch 42/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9500 - val_loss: 0.4745
# Epoch 43/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9500 - val_loss: 0.4795
# Epoch 44/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9500 - val_loss: 0.4840
# Epoch 45/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9500 - val_loss: 0.4858
# Epoch 46/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9500 - val_loss: 0.4872
# Epoch 47/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9958 - loss: 0.0089 - val_accuracy: 0.9500 - val_loss: 0.4933
# Epoch 48/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9333 - val_loss: 0.5039
# Epoch 49/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9333 - val_loss: 0.5072
# Epoch 50/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9333 - val_loss: 0.5072
# Epoch 51/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9500 - val_loss: 0.5081
# Epoch 52/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9500 - val_loss: 0.5076
# Epoch 53/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9500 - val_loss: 0.5099
# Epoch 54/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9333 - val_loss: 0.5259
# Epoch 55/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9500 - val_loss: 0.5199
# Epoch 56/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9500 - val_loss: 0.5202
# Epoch 57/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9500 - val_loss: 0.5224
# Epoch 58/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9500 - val_loss: 0.5216
# Epoch 59/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9500 - val_loss: 0.5224
# Epoch 60/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9500 - val_loss: 0.5260
# Model Eğitimi Tamamlandı.
#
# Adım 8: Model Değerlendirmesi...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9500 - loss: 0.5260
# Test Accuracy: 95.00%
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 315ms/step
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# LeaningOppositeSide       0.93      0.93      0.93        15
#    TooHighAbduction       0.94      1.00      0.97        15
#                True       0.94      1.00      0.97        15
#          WrongElbow       1.00      0.87      0.93        15
#
#            accuracy                           0.95        60
#           macro avg       0.95      0.95      0.95        60
#        weighted avg       0.95      0.95      0.95        60
#
#
# Confusion Matrix:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Adım 9: Model ve diğer nesneler kaydediliyor...
# Tüm dosyalar başarıyla 'final_lstm_models_' klasörüne kaydedildi.

# %%
# Adım 1: Gerekli Kütüphaneleri Yükleme
import os
import numpy as np
import pickle
from pyquaternion import Quaternion # Normalizasyon için
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import classification_report, accuracy_score
import copy # Scaler'ı kopyalamak için

# --- KONFİGÜRASYON ---
DATA_FOLDER = '' 
MOVEMENT_TYPE = '' # Test etmek istediğin hareket
TIMESTEPS = 80 # Veri setindeki (80, 40) şekline göre
NUM_SENSORS = 10
FEATURES_PER_SENSOR = 4 # w, x, y, z
FEATURES = NUM_SENSORS * FEATURES_PER_SENSOR
USERS_TO_ANALYZE = ["User-A", "User-B", "User-C", "User-D", "User-E"] # Analiz edilecek kullanıcılar

# --- Adım 2: Yardımcı Fonksiyonlar ---

def normalize_sequence(sequence_data):
    """
    (N, 40) şeklindeki bir NumPy dizisini ilk karesine göre normalize eder.
    PKL verisinin (w0, x0, y0, z0, ...) sırasıyla geldiğini varsayarak.
    """
    if not sequence_data.any():
        return sequence_data
    
    first_frame = sequence_data[0]
    inverse_references = []
    
    for i in range(NUM_SENSORS):
        offset = i * FEATURES_PER_SENSOR
        w, x, y, z = first_frame[offset], first_frame[offset+1], first_frame[offset+2], first_frame[offset+3]
        
        if w == 0 and x == 0 and y == 0 and z == 0:
             q_ref = Quaternion(1, 0, 0, 0)
        else:
            q_ref = Quaternion(w, x, y, z)
            
        inverse_references.append(q_ref.inverse)
        
    normalized_sequence = []
    
    for frame in sequence_data:
        normalized_frame_features = []
        for i in range(NUM_SENSORS):
            offset = i * FEATURES_PER_SENSOR
            w, x, y, z = frame[offset], frame[offset+1], frame[offset+2], frame[offset+3]
            
            if w == 0 and x == 0 and y == 0 and z == 0:
                q_live = Quaternion(1, 0, 0, 0)
            else:
                q_live = Quaternion(w, x, y, z)
            
            q_normalized = inverse_references[i] * q_live
            normalized_frame_features.extend([q_normalized.w, q_normalized.x, q_normalized.y, q_normalized.z])
        
        normalized_sequence.append(normalized_frame_features)
        
    return np.array(normalized_sequence)

def build_model(num_classes):
    """
    Her döngüde yeniden, taze bir model oluşturmak için fonksiyon.
    """
    model = Sequential([
        LSTM(64, input_shape=(TIMESTEPS, FEATURES), return_sequences=True),
        BatchNormalization(),
        Dropout(0.3),
        LSTM(32, return_sequences=False),
        BatchNormalization(),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# --- Adım 3: Veriyi Kullanıcılara Göre Yükleme ---
print("Adım 3: Veri Kullanıcılara Göre Yükleniyor...")

# Veriyi { 'User-A': {'data': [...], 'labels': [...]}, ... } şeklinde saklayalım
data_by_user = {}
all_labels_flat = [] # Tüm etiketleri toplamak için

movement_path = os.path.join(DATA_FOLDER, MOVEMENT_TYPE)

for user_folder in USERS_TO_ANALYZE:
    user_path = os.path.join(movement_path, user_folder)
    if not os.path.isdir(user_path):
        print(f"Uyarı: Kullanıcı klasörü atlanıyor (bulunamadı): {user_path}")
        continue

    print(f"Kullanıcı yükleniyor: {user_folder}")
    data_by_user[user_folder] = {'data': [], 'labels': []}

    for label_folder in os.listdir(user_path):
        label_path = os.path.join(user_path, label_folder)
        if os.path.isdir(label_path):
            for pkl_file in os.listdir(label_path):
                if pkl_file.endswith('.pkl'):
                    file_path = os.path.join(label_path, pkl_file)
                    try:
                        with open(file_path, 'rb') as f:
                            obj = pickle.load(f)

                        recording_data = np.array(obj['data'])

                        if recording_data.shape[0] < 1 or recording_data.shape[1] != FEATURES:
                            continue

                        recording_data_normalized = normalize_sequence(recording_data)

                        data_by_user[user_folder]['data'].append(recording_data_normalized)
                        data_by_user[user_folder]['labels'].append(label_folder)
                        all_labels_flat.append(label_folder)

                    except Exception as e:
                        print(f"Hata: {file_path} dosyası okunurken hata oluştu: {e}")

print("Veri Yükleme Tamamlandı.\n")


# --- Adım 4: Etiket Kodlayıcıyı (LabelEncoder) Hazırlama ---
# LabelEncoder'ın TÜM olası etiketleri bilmesi için onu döngüden önce eğitiyoruz.
print("Adım 4: Etiket Kodlayıcı Hazırlanıyor...")
label_encoder = LabelEncoder()
label_encoder.fit(all_labels_flat)
num_classes = len(label_encoder.classes_)
print(f"Bulunan sınıflar ({num_classes} adet): {label_encoder.classes_}\n")


# --- Adım 5: Leave-One-User-Out Çapraz Doğrulama (LOUOCV) Döngüsü ---
print("Adım 5: LOUOCV Başlatılıyor...")

all_scores = []
all_reports = {}

# Her bir kullanıcıyı sırayla test seti olarak ayır
for user_to_test in USERS_TO_ANALYZE:
    print(f"-------------------------------------------------")
    print(f"TEST KULLANICISI: {user_to_test}")
    print(f"-------------------------------------------------")
    
    # 1. Eğitim ve Test Verisini Ayır
    X_train_raw = []
    y_train_raw = []
    
    # Test verisi, dışarıda bırakılan kullanıcıdır
    X_test_raw = data_by_user[user_to_test]['data']
    y_test_raw = data_by_user[user_to_test]['labels']
    
    # Geri kalan tüm kullanıcılar eğitim verisidir
    for user_to_train in USERS_TO_ANALYZE:
        if user_to_train == user_to_test:
            continue # Test kullanıcısını atla
        X_train_raw.extend(data_by_user[user_to_train]['data'])
        y_train_raw.extend(data_by_user[user_to_train]['labels'])
        
    # 2. Boyut Eşitleme (Padding/Trimming)
    X_train = pad_sequences(X_train_raw, maxlen=TIMESTEPS, dtype='float32', padding='post', truncating='post')
    X_test = pad_sequences(X_test_raw, maxlen=TIMESTEPS, dtype='float32', padding='post', truncating='post')
    
    # 3. Etiketleri Kodlama (fit etmeden, sadece transform)
    y_train_encoded = label_encoder.transform(y_train_raw)
    y_test_encoded = label_encoder.transform(y_test_raw)
    
    y_train = to_categorical(y_train_encoded, num_classes=num_classes)
    y_test = to_categorical(y_test_encoded, num_classes=num_classes)

    # 4. Ölçekleme (Scaler'ı SADECE EĞİTİM VERİSİNE GÖRE EĞİT)
    scaler = StandardScaler()
    X_train_reshaped = X_train.reshape(-1, FEATURES)
    scaler.fit(X_train_reshaped) # Sadece eğitim verisine fit et
    
    X_train_scaled = scaler.transform(X_train_reshaped).reshape(X_train.shape)
    X_test_scaled = scaler.transform(X_test.reshape(-1, FEATURES)).reshape(X_test.shape)

    # 5. Modeli Oluştur ve Eğit
    print(f"{user_to_test} dışarıda, {len(X_train)} kayıt ile model eğitiliyor...")
    model = build_model(num_classes)
    
    history = model.fit(
        X_train_scaled, 
        y_train, 
        epochs=60, 
        batch_size=16, 
        validation_data=(X_test_scaled, y_test), # Test kullanıcısını validasyon olarak kullan
        verbose=0 # (Eğitim loglarını gizle, sadece sonu gör)
    )
    
    # 6. Modeli Değerlendir
    loss, accuracy = model.evaluate(X_test_scaled, y_test, verbose=0)
    all_scores.append(accuracy)
    
    y_pred_probs = model.predict(X_test_scaled)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_test_labels = np.argmax(y_test, axis=1)
    
    print(f"\n{user_to_test} Test Sonuçları (Accuracy: {accuracy*100:.2f}%):")
    report = classification_report(y_test_labels, y_pred, target_names=label_encoder.classes_)
    print(report)
    all_reports[user_to_test] = report

print("\n\n--- LOUOCV GENEL SONUÇLARI ---")
for i, user in enumerate(USERS_TO_ANALYZE):
    print(f"{user} Test Doğruluğu: {all_scores[i] * 100:.2f}%")

print(f"\nOrtalama Test Doğruluğu (Genelleme Yeteneği): {np.mean(all_scores) * 100:.2f}%")
# Out:
# Adım 3: Veri Kullanıcılara Göre Yükleniyor...
# Kullanıcı yükleniyor: User-A
# Kullanıcı yükleniyor: User-B
# Kullanıcı yükleniyor: User-C
# Kullanıcı yükleniyor: User-D
# Kullanıcı yükleniyor: User-E
# Veri Yükleme Tamamlandı.
#
# Adım 4: Etiket Kodlayıcı Hazırlanıyor...
# Bulunan sınıflar (4 adet): ['LeaningOppositeSide' 'TooHighAbduction' 'True' 'WrongElbow']
#
# Adım 5: LOUOCV Başlatılıyor...
# -------------------------------------------------
# TEST KULLANICISI: User-A
# -------------------------------------------------
# User-A dışarıda, 240 kayıt ile model eğitiliyor...
# /opt/conda/envs/python313/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7efcd078c0e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7efcd078c0e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/stepWARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7efcd078c0e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7efcd078c0e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 306ms/step
#
# User-A Test Sonuçları (Accuracy: 48.33%):
#                      precision    recall  f1-score   support
#
# LeaningOppositeSide       1.00      0.20      0.33        15
#    TooHighAbduction       0.85      0.73      0.79        15
#                True       0.31      0.87      0.46        15
#          WrongElbow       1.00      0.13      0.24        15
#
#            accuracy                           0.48        60
#           macro avg       0.79      0.48      0.45        60
#        weighted avg       0.79      0.48      0.45        60
#
# -------------------------------------------------
# TEST KULLANICISI: User-B
# -------------------------------------------------
# User-B dışarıda, 240 kayıt ile model eğitiliyor...
# /opt/conda/envs/python313/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 307ms/step
#
# User-B Test Sonuçları (Accuracy: 73.33%):
#                      precision    recall  f1-score   support
#
# LeaningOppositeSide       0.86      0.80      0.83        15
#    TooHighAbduction       1.00      0.33      0.50        15
#                True       0.52      1.00      0.68        15
#          WrongElbow       1.00      0.80      0.89        15
#
#            accuracy                           0.73        60
#           macro avg       0.84      0.73      0.72        60
#        weighted avg       0.84      0.73      0.72        60
#
# -------------------------------------------------
# TEST KULLANICISI: User-C
# -------------------------------------------------
# User-C dışarıda, 240 kayıt ile model eğitiliyor...
# /opt/conda/envs/python313/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 326ms/step
#
# User-C Test Sonuçları (Accuracy: 35.00%):
#                      precision    recall  f1-score   support
#
# LeaningOppositeSide       0.71      0.33      0.45        15
#    TooHighAbduction       0.20      0.07      0.10        15
#                True       0.31      1.00      0.48        15
#          WrongElbow       0.00      0.00      0.00        15
#
#            accuracy                           0.35        60
#           macro avg       0.31      0.35      0.26        60
#        weighted avg       0.31      0.35      0.26        60
#
# -------------------------------------------------
# TEST KULLANICISI: User-D
# -------------------------------------------------
# User-D dışarıda, 240 kayıt ile model eğitiliyor...
# /opt/conda/envs/python313/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/envs/python313/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/envs/python313/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/envs/python313/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 308ms/step
#
# User-D Test Sonuçları (Accuracy: 48.33%):
#                      precision    recall  f1-score   support
#
# LeaningOppositeSide       0.40      0.40      0.40        15
#    TooHighAbduction       0.33      0.07      0.11        15
#                True       0.73      0.53      0.62        15
#          WrongElbow       0.45      0.93      0.61        15
#
#            accuracy                           0.48        60
#           macro avg       0.48      0.48      0.43        60
#        weighted avg       0.48      0.48      0.43        60
#
# -------------------------------------------------
# TEST KULLANICISI: User-E
# -------------------------------------------------
# User-E dışarıda, 240 kayıt ile model eğitiliyor...
# /opt/conda/envs/python313/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 321ms/step
#
# User-E Test Sonuçları (Accuracy: 43.33%):
#                      precision    recall  f1-score   support
#
# LeaningOppositeSide       0.42      0.33      0.37        15
#    TooHighAbduction       0.40      0.13      0.20        15
#                True       0.38      0.93      0.54        15
#          WrongElbow       0.83      0.33      0.48        15
#
#            accuracy                           0.43        60
#           macro avg       0.51      0.43      0.40        60
#        weighted avg       0.51      0.43      0.40        60
#
#
#
# --- LOUOCV GENEL SONUÇLARI ---
# User-A Test Doğruluğu: 48.33%
# User-B Test Doğruluğu: 73.33%
# User-C Test Doğruluğu: 35.00%
# User-D Test Doğruluğu: 48.33%
# User-E Test Doğruluğu: 43.33%
#
# Ortalama Test Doğruluğu (Genelleme Yeteneği): 49.67%

# %%
# Adım 1: Gerekli Kütüphaneleri Yükleme
import os
import numpy as np
import pickle
from pyquaternion import Quaternion # Normalizasyon için
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.layers import Conv1D, MaxPooling1D
import matplotlib.pyplot as plt

# --- KONFİGÜRASYON ---
# Verinin bulunduğu ana klasör
DATA_FOLDER = '' 
# Hangi hareketi eğitmek istiyoruz?
MOVEMENT_TYPE = ''
# Tüm zaman serilerini eşitleyeceğimiz uzunluk (gördüğümüz 80-82'ye göre 80 ideal)
TIMESTEPS = 80
NUM_SENSORS = 10
FEATURES_PER_SENSOR = 4 # w, x, y, z
FEATURES = NUM_SENSORS * FEATURES_PER_SENSOR # Toplam 40 özellik
USERS_TO_ANALYZE = ["User-A","User-B","User-C", "User-D", "User-E"]


# --- Adım 2.1: Normalizasyon için Yardımcı Fonksiyon ---

def normalize_sequence(sequence_data):
    """
    (N, 40) şeklindeki bir NumPy dizisini ilk karesine göre normalize eder.
    Sıralamanın (w, x, y, z) olduğunu varsayar.
    """
    if not sequence_data.any(): # Tamamen sıfırsa dokunma
        return sequence_data
    
    # 1. İlk kareyi (referans yönelimi) al
    first_frame = sequence_data[0] # (40,) şeklinde
    inverse_references = []
    
    # 2. 10 sensör için de ters (inverse) quaternion'ları hesapla
    for i in range(NUM_SENSORS):
        offset = i * FEATURES_PER_SENSOR
        w, x, y, z = first_frame[offset], first_frame[offset+1], first_frame[offset+2], first_frame[offset+3]
        
        # Olası bir sıfır veriye karşı koruma
        if w == 0 and x == 0 and y == 0 and z == 0:
             q_ref = Quaternion(1, 0, 0, 0) # Nötr (identity) quaternion
        else:
            q_ref = Quaternion(w, x, y, z)
            
        inverse_references.append(q_ref.inverse)
        
    normalized_sequence = []
    
    # 3. Tüm zaman adımlarını (timesteps) bu referanslara göre normalize et
    for frame in sequence_data:
        normalized_frame_features = []
        for i in range(NUM_SENSORS):
            offset = i * FEATURES_PER_SENSOR
            w, x, y, z = frame[offset], frame[offset+1], frame[offset+2], frame[offset+3]
            
            if w == 0 and x == 0 and y == 0 and z == 0:
                q_live = Quaternion(1, 0, 0, 0)
            else:
                q_live = Quaternion(w, x, y, z)
            
            # Referans yönelimi çıkar
            q_normalized = inverse_references[i] * q_live
            
            # Yeni (w,x,y,z) değerlerini düz listeye ekle
            normalized_frame_features.extend([q_normalized.w, q_normalized.x, q_normalized.y, q_normalized.z])
        
        normalized_sequence.append(normalized_frame_features)
        
    return np.array(normalized_sequence)


def augment_data(sequence_data, noise_level=0.01):
    """Veriye rastgele küçük gürültüler (jitter) ekler."""
    noise = np.random.normal(0, noise_level, sequence_data.shape)
    return sequence_data + noise
# --- Adım 2: Veriyi Yükleme ve Ön İşleme ---
print("Adım 2: Veri Yükleme ve Ön İşleme Başladı...")

all_data = []
all_labels = []

movement_path = os.path.join(DATA_FOLDER, MOVEMENT_TYPE)
# User-A, User-B, ... klasörlerinde gezin
for user_folder in USERS_TO_ANALYZE:
    user_path = os.path.join(movement_path, user_folder)
    if os.path.isdir(user_path) and user_folder.startswith('User-'):

        # True, WrongElbow, ... klasörlerinde gezin
        for label_folder in os.listdir(user_path):
            label_path = os.path.join(user_path, label_folder)
            if os.path.isdir(label_path):

                # .pkl dosyalarını oku
                for pkl_file in os.listdir(label_path):
                    if pkl_file.endswith('.pkl'):
                        file_path = os.path.join(label_path, pkl_file)

                        try:
                            with open(file_path, 'rb') as f:
                                obj = pickle.load(f)

                            # .pkl içindeki 'data' anahtarından veriyi al
                            recording_data = np.array(obj['data'])

                            # Veri geçerli mi diye kontrol et (en az 1 frame olmalı)
                            if recording_data.shape[0] < 1 or recording_data.shape[1] != FEATURES:
                                print(f"Uyarı: Hatalı veri atlanıyor (şekil {recording_data.shape}): {file_path}")
                                continue

                            # --- YENİ: Normalizasyon ---
                            recording_data_normalized = normalize_sequence(recording_data)
                                
                            # --- YENİ ADIM: Veri Artırma ---
                            # Orijinal veriyi ekle
                            all_data.append(recording_data_normalized)
                            all_labels.append(label_folder)

                            # Bir de gürültü eklenmiş (jittered) 2 kopya ekle
                            all_data.append(augment_data(recording_data_normalized, 0.01))
                            all_labels.append(label_folder)

                            all_data.append(augment_data(recording_data_normalized, 0.005))
                            all_labels.append(label_folder)

                        except Exception as e:
                            print(f"Hata: {file_path} dosyası okunurken hata oluştu: {e}")

print(f"Toplam {len(all_data)} adet .pkl kaydı yüklendi.")

# --- Adım 3: Boyut Eşitleme (Padding/Trimming) ---
print(f"Adım 3: Tüm veriler {TIMESTEPS} adımına eşitleniyor...")

# Keras'ın 'pad_sequences' fonksiyonunu kullanalım. Çok daha verimli.
# 'post' = eksik veriyi sona ekle/sondan kırp
X_padded = pad_sequences(
    all_data, 
    maxlen=TIMESTEPS, 
    dtype='float32', 
    padding='post', 
    truncating='post'
)

print("Boyut Eşitleme Tamamlandı.\n")


# --- Adım 4: Veriyi Derin Öğrenme Formatına Dönüştürme ---
print("Adım 4: Veriyi Derin Öğrenme Formatına Dönüştürme Başladı...")

X = X_padded # Artık tüm verilerimiz (sample_sayısı, 80, 40) şeklinde
y = np.array(all_labels)

# Etiketleri sayısal değerlere çevir (örn: 'Correct' -> 0, 'WrongElbow' -> 1)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Sınıf sayısını al
num_classes = len(label_encoder.classes_)
print(f"Bulunan sınıflar ({num_classes} adet): {label_encoder.classes_}")

# Sayısal etiketleri one-hot encoding formatına çevir
# Örn: 3 sınıf varsa, 1 -> [0, 1, 0]
y_one_hot = to_categorical(y_encoded, num_classes=num_classes)

print(f"Veri şekli (X): {X.shape}")
print(f"Etiket şekli (y): {y_one_hot.shape}")
print("Veri Dönüştürme Tamamlandı.\n")


# --- Adım 5: Eğitim ve Test Verisi Olarak Ayırma ve Ölçekleme ---
print("Adım 5: Veriyi Ayırma ve Ölçekleme Başladı...")

X_train, X_test, y_train, y_test = train_test_split(
    X, y_one_hot, 
    test_size=0.2,       # Verinin %20'sini test için ayır
    random_state=42,     # Tekrarlanabilir sonuçlar için
    stratify=y_one_hot   # Sınıf dağılımını koru (çok önemli)
)

# Ölçekleme (Scaling) için veriyi 2D'ye çevirmemiz gerekiyor
# (sample_sayısı, 80, 40) -> (sample_sayısı * 80, 40)
scaler = StandardScaler()
X_train_reshaped = X_train.reshape(-1, FEATURES)
scaler.fit(X_train_reshaped)

X_train_scaled_reshaped = scaler.transform(X_train_reshaped)
X_test_scaled_reshaped = scaler.transform(X_test.reshape(-1, FEATURES))

# Veriyi tekrar 3D (LSTM formatı) haline getirelim
X_train_scaled = X_train_scaled_reshaped.reshape(X_train.shape)
X_test_scaled = X_test_scaled_reshaped.reshape(X_test.shape)

print(f"Eğitim verisi: {X_train_scaled.shape}, Test verisi: {X_test_scaled.shape}")
print("Veri Ayırma ve Ölçekleme Tamamlandı.\n")


# --- Adım 6: CNN-LSTM Modelini Oluşturma ---
print("Adım 6: CNN-LSTM Hibrid Modeli Oluşturuluyor...")

model = Sequential([
    # 1. 1D-CNN Katmanı: Zaman serisi verisinden özellik çıkarır
    Conv1D(
        filters=64, 
        kernel_size=3, # 3 zaman adımına aynı anda bakar
        activation='relu', 
        input_shape=(TIMESTEPS, FEATURES)
    ),
    Conv1D(filters=64, kernel_size=3, activation='relu'),
    MaxPooling1D(pool_size=2),
    BatchNormalization(),
    Dropout(0.3),
    
    # 2. LSTM Katmanı: Çıkarılan özelliklerin zamansal desenini öğrenir
    LSTM(50, return_sequences=False),
    BatchNormalization(),
    Dropout(0.3),
    
    # 3. Çıkış Katmanı
    Dense(32, activation='relu'),
    Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
print("Model Oluşturma Tamamlandı.\n")

# --- Adım 7: Modeli Eğitme ---
print("Adım 7: Model Eğitimi Başlıyor...")

history = model.fit(
    X_train_scaled, 
    y_train, 
    epochs=60, # Epoch sayısını 50-100 arası deneyebilirsin
    batch_size=16, 
    validation_data=(X_test_scaled, y_test)
)

print("Model Eğitimi Tamamlandı.\n")


# --- Adım 8: Modeli Değerlendirme ---
print("Adım 8: Model Değerlendirmesi...")

# Test verisi üzerindeki loss ve accuracy değerleri
loss, accuracy = model.evaluate(X_test_scaled, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")

# Tahminleri yap
y_pred_probs = model.predict(X_test_scaled)
y_pred = np.argmax(y_pred_probs, axis=1) # Olasılıklardan en yüksek sınıfı seç
y_test_labels = np.argmax(y_test, axis=1) # One-hot'tan normal etikete dön

# Sınıflandırma Raporu (Precision, Recall, F1-score)
print("\nClassification Report:")
print(classification_report(y_test_labels, y_pred, target_names=label_encoder.classes_))

# Karışıklık Matrisi (Confusion Matrix)
print("\nConfusion Matrix:")
cm = confusion_matrix(y_test_labels, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='Blues', 
    xticklabels=label_encoder.classes_, 
    yticklabels=label_encoder.classes_
)
plt.xlabel('Tahmin Edilen (Predicted)')
plt.ylabel('Gerçek (True)')
plt.show()


# --- Adım 9: Modeli ve Gerekli Nesneleri Kaydetme ---
print("\nAdım 9: Model ve diğer nesneler kaydediliyor...")

MODEL_OUTPUT_DIR = f"final_lstm_models_{MOVEMENT_TYPE}"
if not os.path.exists(MODEL_OUTPUT_DIR):
    os.makedirs(MODEL_OUTPUT_DIR)

# 1. Keras modelini kaydet
model.save(os.path.join(MODEL_OUTPUT_DIR, f'{MOVEMENT_TYPE}_lstm_model.h5'))

# 2. Scaler'ı kaydet
with open(os.path.join(MODEL_OUTPUT_DIR, f'{MOVEMENT_TYPE}_scaler.pkl'), 'wb') as f:
    pickle.dump(scaler, f)

# 3. Label Encoder'ı kaydet
with open(os.path.join(MODEL_OUTPUT_DIR, f'{MOVEMENT_TYPE}_label_encoder.pkl'), 'wb') as f:
    pickle.dump(label_encoder, f)

print(f"Tüm dosyalar başarıyla '{MODEL_OUTPUT_DIR}' klasörüne kaydedildi.")
# Out:
# 2025-10-27 19:51:53.882095: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-27 19:51:53.882585: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-27 19:51:53.962187: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-27 19:51:55.431304: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-27 19:51:55.432991: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# Adım 2: Veri Yükleme ve Ön İşleme Başladı...
# Toplam 900 adet .pkl kaydı yüklendi.
# Adım 3: Tüm veriler 80 adımına eşitleniyor...
# Boyut Eşitleme Tamamlandı.
#
# Adım 4: Veriyi Derin Öğrenme Formatına Dönüştürme Başladı...
# Bulunan sınıflar (4 adet): ['LeaningOppositeSide' 'TooHighAbduction' 'True' 'WrongElbow']
# Veri şekli (X): (900, 80, 40)
# Etiket şekli (y): (900, 4)
# Veri Dönüştürme Tamamlandı.
#
# Adım 5: Veriyi Ayırma ve Ölçekleme Başladı...
# Eğitim verisi: (720, 80, 40), Test verisi: (180, 80, 40)
# Veri Ayırma ve Ölçekleme Tamamlandı.
#
# Adım 6: CNN-LSTM Hibrid Modeli Oluşturuluyor...
# /opt/conda/envs/python313/lib/python3.13/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-10-27 19:51:59.438242: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 78, 64)         │         7,744 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 76, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 38, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 38, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 38, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 50)             │        23,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 50)             │           200 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         1,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 45,316 (177.02 KB)
#  Trainable params: 45,088 (176.12 KB)
#  Non-trainable params: 228 (912.00 B)
# Model Oluşturma Tamamlandı.
#
# Adım 7: Model Eğitimi Başlıyor...
# Epoch 1/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.5069 - loss: 1.1666 - val_accuracy: 0.3222 - val_loss: 1.2286
# Epoch 2/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8361 - loss: 0.5121 - val_accuracy: 0.7889 - val_loss: 0.7665
# Epoch 3/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9514 - loss: 0.2120 - val_accuracy: 0.9944 - val_loss: 0.2197
# Epoch 4/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9861 - loss: 0.0827 - val_accuracy: 0.9944 - val_loss: 0.0759
# Epoch 5/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9806 - loss: 0.0847 - val_accuracy: 1.0000 - val_loss: 0.0244
# Epoch 6/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9833 - loss: 0.0837 - val_accuracy: 1.0000 - val_loss: 0.0114
# Epoch 7/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9875 - loss: 0.0481 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 8/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9944 - loss: 0.0229 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 9/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9972 - loss: 0.0137 - val_accuracy: 1.0000 - val_loss: 5.7652e-04
# Epoch 10/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9903 - loss: 0.0314 - val_accuracy: 1.0000 - val_loss: 4.9367e-04
# Epoch 11/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9847 - loss: 0.0625 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 12/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9764 - loss: 0.0886 - val_accuracy: 0.9944 - val_loss: 0.0393
# Epoch 13/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9750 - loss: 0.1149 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 14/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9931 - loss: 0.0241 - val_accuracy: 1.0000 - val_loss: 6.4621e-04
# Epoch 15/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9958 - loss: 0.0136 - val_accuracy: 1.0000 - val_loss: 4.1697e-04
# Epoch 16/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9986 - loss: 0.0122 - val_accuracy: 1.0000 - val_loss: 2.0032e-04
# Epoch 17/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9972 - loss: 0.0141 - val_accuracy: 1.0000 - val_loss: 1.5337e-04
# Epoch 18/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9958 - loss: 0.0150 - val_accuracy: 1.0000 - val_loss: 1.4088e-04
# Epoch 19/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9972 - loss: 0.0166 - val_accuracy: 1.0000 - val_loss: 0.0075
# Epoch 20/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9944 - loss: 0.0219 - val_accuracy: 1.0000 - val_loss: 2.4695e-04
# Epoch 21/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9986 - loss: 0.0073 - val_accuracy: 1.0000 - val_loss: 2.1668e-04
# Epoch 22/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9986 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 1.0931e-04
# Epoch 23/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 1.0834e-04
# Epoch 24/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9875 - loss: 0.0472 - val_accuracy: 0.9556 - val_loss: 0.2251
# Epoch 25/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9958 - loss: 0.0240 - val_accuracy: 1.0000 - val_loss: 1.4887e-04
# Epoch 26/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9972 - loss: 0.0093 - val_accuracy: 1.0000 - val_loss: 1.4456e-04
# Epoch 27/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9986 - loss: 0.0083 - val_accuracy: 1.0000 - val_loss: 8.5324e-05
# Epoch 28/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9958 - loss: 0.0130 - val_accuracy: 1.0000 - val_loss: 2.9066e-04
# Epoch 29/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9958 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 7.5416e-05
# Epoch 30/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9986 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 5.4496e-05
# Epoch 31/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9986 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 4.5921e-05
# Epoch 32/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9972 - loss: 0.0107 - val_accuracy: 1.0000 - val_loss: 1.3171e-04
# Epoch 33/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9944 - loss: 0.0158 - val_accuracy: 1.0000 - val_loss: 1.6057e-04
# Epoch 34/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 7.2532e-05
# Epoch 35/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9986 - loss: 0.0056 - val_accuracy: 0.9944 - val_loss: 0.0397
# Epoch 36/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9931 - loss: 0.0361 - val_accuracy: 1.0000 - val_loss: 9.6146e-05
# Epoch 37/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 6.3175e-05
# Epoch 38/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9972 - loss: 0.0141 - val_accuracy: 1.0000 - val_loss: 5.0349e-05
# Epoch 39/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9986 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 3.6183e-05
# Epoch 40/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9986 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 4.7859e-05
# Epoch 41/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 3.1701e-05
# Epoch 42/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9972 - loss: 0.0148 - val_accuracy: 1.0000 - val_loss: 3.3662e-05
# Epoch 43/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9736 - loss: 0.1706 - val_accuracy: 0.9833 - val_loss: 0.0448
# Epoch 44/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9944 - loss: 0.0185 - val_accuracy: 1.0000 - val_loss: 4.8270e-04
# Epoch 45/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9958 - loss: 0.0230 - val_accuracy: 1.0000 - val_loss: 2.6843e-04
# Epoch 46/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9986 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 2.4350e-04
# Epoch 47/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 1.9779e-04
# Epoch 48/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 1.0000 - val_loss: 9.2235e-05
# Epoch 49/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 6.2980e-05
# Epoch 50/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9972 - loss: 0.0209 - val_accuracy: 1.0000 - val_loss: 6.0921e-05
# Epoch 51/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9972 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 1.3236e-04
# Epoch 52/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9972 - loss: 0.0147 - val_accuracy: 1.0000 - val_loss: 1.0301e-04
# Epoch 53/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 5.4044e-05
# Epoch 54/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 4.1191e-05
# Epoch 55/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9986 - loss: 0.0141 - val_accuracy: 1.0000 - val_loss: 6.5478e-05
# Epoch 56/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 5.5999e-05
# Epoch 57/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 4.6306e-05
# Epoch 58/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 7.5501e-04 - val_accuracy: 1.0000 - val_loss: 3.7102e-05
# Epoch 59/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 5.4481e-04 - val_accuracy: 1.0000 - val_loss: 3.3694e-05
# Epoch 60/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 6.1778e-04 - val_accuracy: 1.0000 - val_loss: 2.8475e-05
# Model Eğitimi Tamamlandı.
#
# Adım 8: Model Değerlendirmesi...
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 2.8475e-05
# Test Accuracy: 100.00%
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# LeaningOppositeSide       1.00      1.00      1.00        45
#    TooHighAbduction       1.00      1.00      1.00        45
#                True       1.00      1.00      1.00        45
#          WrongElbow       1.00      1.00      1.00        45
#
#            accuracy                           1.00       180
#           macro avg       1.00      1.00      1.00       180
#        weighted avg       1.00      1.00      1.00       180
#
#
# Confusion Matrix:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Adım 9: Model ve diğer nesneler kaydediliyor...
# Tüm dosyalar başarıyla 'final_lstm_models_' klasörüne kaydedildi.

# %%
# Adım 1: Gerekli Kütüphaneleri Yükleme
import os
import numpy as np
import pickle
from pyquaternion import Quaternion # Normalizasyon için
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.layers import Conv1D, MaxPooling1D
import matplotlib.pyplot as plt

# --- KONFİGÜRASYON ---
# Verinin bulunduğu ana klasör
DATA_FOLDER = '' 
# Hangi hareketi eğitmek istiyoruz?
MOVEMENT_TYPE = ''
# Tüm zaman serilerini eşitleyeceğimiz uzunluk (gördüğümüz 80-82'ye göre 80 ideal)
TIMESTEPS = 80
NUM_SENSORS = 10
FEATURES_PER_SENSOR = 4 # w, x, y, z
FEATURES = NUM_SENSORS * FEATURES_PER_SENSOR # Toplam 40 özellik
USERS_TO_ANALYZE = ["User-A","User-B","User-C", "User-D", "User-E"]


# --- Adım 2.1: Normalizasyon için Yardımcı Fonksiyon ---

def normalize_sequence(sequence_data):
    """
    (N, 40) şeklindeki bir NumPy dizisini ilk karesine göre normalize eder.
    Sıralamanın (w, x, y, z) olduğunu varsayar.
    """
    if not sequence_data.any(): # Tamamen sıfırsa dokunma
        return sequence_data
    
    # 1. İlk kareyi (referans yönelimi) al
    first_frame = sequence_data[0] # (40,) şeklinde
    inverse_references = []
    
    # 2. 10 sensör için de ters (inverse) quaternion'ları hesapla
    for i in range(NUM_SENSORS):
        offset = i * FEATURES_PER_SENSOR
        w, x, y, z = first_frame[offset], first_frame[offset+1], first_frame[offset+2], first_frame[offset+3]
        
        # Olası bir sıfır veriye karşı koruma
        if w == 0 and x == 0 and y == 0 and z == 0:
             q_ref = Quaternion(1, 0, 0, 0) # Nötr (identity) quaternion
        else:
            q_ref = Quaternion(w, x, y, z)
            
        inverse_references.append(q_ref.inverse)
        
    normalized_sequence = []
    
    # 3. Tüm zaman adımlarını (timesteps) bu referanslara göre normalize et
    for frame in sequence_data:
        normalized_frame_features = []
        for i in range(NUM_SENSORS):
            offset = i * FEATURES_PER_SENSOR
            w, x, y, z = frame[offset], frame[offset+1], frame[offset+2], frame[offset+3]
            
            if w == 0 and x == 0 and y == 0 and z == 0:
                q_live = Quaternion(1, 0, 0, 0)
            else:
                q_live = Quaternion(w, x, y, z)
            
            # Referans yönelimi çıkar
            q_normalized = inverse_references[i] * q_live
            
            # Yeni (w,x,y,z) değerlerini düz listeye ekle
            normalized_frame_features.extend([q_normalized.w, q_normalized.x, q_normalized.y, q_normalized.z])
        
        normalized_sequence.append(normalized_frame_features)
        
    return np.array(normalized_sequence)


def augment_data(sequence_data, noise_level=0.01):
    """Veriye rastgele küçük gürültüler (jitter) ekler."""
    noise = np.random.normal(0, noise_level, sequence_data.shape)
    return sequence_data + noise
# --- Adım 2: Veriyi Yükleme ve Ön İşleme ---
print("Adım 2: Veri Yükleme ve Ön İşleme Başladı...")

all_data = []
all_labels = []

movement_path = os.path.join(DATA_FOLDER, MOVEMENT_TYPE)
# User-A, User-B, ... klasörlerinde gezin
for user_folder in USERS_TO_ANALYZE:
    user_path = os.path.join(movement_path, user_folder)
    if os.path.isdir(user_path) and user_folder.startswith('User-'):

        # True, WrongElbow, ... klasörlerinde gezin
        for label_folder in os.listdir(user_path):
            label_path = os.path.join(user_path, label_folder)
            if os.path.isdir(label_path):

                # .pkl dosyalarını oku
                for pkl_file in os.listdir(label_path):
                    if pkl_file.endswith('.pkl'):
                        file_path = os.path.join(label_path, pkl_file)

                        try:
                            with open(file_path, 'rb') as f:
                                obj = pickle.load(f)

                            # .pkl içindeki 'data' anahtarından veriyi al
                            recording_data = np.array(obj['data'])

                            # Veri geçerli mi diye kontrol et (en az 1 frame olmalı)
                            if recording_data.shape[0] < 1 or recording_data.shape[1] != FEATURES:
                                print(f"Uyarı: Hatalı veri atlanıyor (şekil {recording_data.shape}): {file_path}")
                                continue

                            # --- YENİ: Normalizasyon ---
                            recording_data_normalized = normalize_sequence(recording_data)
                                
                            # --- YENİ ADIM: Veri Artırma ---
                            # Orijinal veriyi ekle
                            all_data.append(recording_data_normalized)
                            all_labels.append(label_folder)

                            # Bir de gürültü eklenmiş (jittered) 2 kopya ekle
                            #all_data.append(augment_data(recording_data_normalized, 0.01))
                            #all_labels.append(label_folder)

                            #all_data.append(augment_data(recording_data_normalized, 0.005))
                            #all_labels.append(label_folder)

                        except Exception as e:
                            print(f"Hata: {file_path} dosyası okunurken hata oluştu: {e}")

print(f"Toplam {len(all_data)} adet .pkl kaydı yüklendi.")

# --- Adım 3: Boyut Eşitleme (Padding/Trimming) ---
print(f"Adım 3: Tüm veriler {TIMESTEPS} adımına eşitleniyor...")

# Keras'ın 'pad_sequences' fonksiyonunu kullanalım. Çok daha verimli.
# 'post' = eksik veriyi sona ekle/sondan kırp
X_padded = pad_sequences(
    all_data, 
    maxlen=TIMESTEPS, 
    dtype='float32', 
    padding='post', 
    truncating='post'
)

print("Boyut Eşitleme Tamamlandı.\n")


# --- Adım 4: Veriyi Derin Öğrenme Formatına Dönüştürme ---
print("Adım 4: Veriyi Derin Öğrenme Formatına Dönüştürme Başladı...")

X = X_padded # Artık tüm verilerimiz (sample_sayısı, 80, 40) şeklinde
y = np.array(all_labels)

# Etiketleri sayısal değerlere çevir (örn: 'Correct' -> 0, 'WrongElbow' -> 1)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Sınıf sayısını al
num_classes = len(label_encoder.classes_)
print(f"Bulunan sınıflar ({num_classes} adet): {label_encoder.classes_}")

# Sayısal etiketleri one-hot encoding formatına çevir
# Örn: 3 sınıf varsa, 1 -> [0, 1, 0]
y_one_hot = to_categorical(y_encoded, num_classes=num_classes)

print(f"Veri şekli (X): {X.shape}")
print(f"Etiket şekli (y): {y_one_hot.shape}")
print("Veri Dönüştürme Tamamlandı.\n")


# --- Adım 5: Eğitim ve Test Verisi Olarak Ayırma ve Ölçekleme ---
print("Adım 5: Veriyi Ayırma ve Ölçekleme Başladı...")

X_train, X_test, y_train, y_test = train_test_split(
    X, y_one_hot, 
    test_size=0.2,       # Verinin %20'sini test için ayır
    random_state=42,     # Tekrarlanabilir sonuçlar için
    stratify=y_one_hot   # Sınıf dağılımını koru (çok önemli)
)

# Ölçekleme (Scaling) için veriyi 2D'ye çevirmemiz gerekiyor
# (sample_sayısı, 80, 40) -> (sample_sayısı * 80, 40)
scaler = StandardScaler()
X_train_reshaped = X_train.reshape(-1, FEATURES)
scaler.fit(X_train_reshaped)

X_train_scaled_reshaped = scaler.transform(X_train_reshaped)
X_test_scaled_reshaped = scaler.transform(X_test.reshape(-1, FEATURES))

# Veriyi tekrar 3D (LSTM formatı) haline getirelim
X_train_scaled = X_train_scaled_reshaped.reshape(X_train.shape)
X_test_scaled = X_test_scaled_reshaped.reshape(X_test.shape)

print(f"Eğitim verisi: {X_train_scaled.shape}, Test verisi: {X_test_scaled.shape}")
print("Veri Ayırma ve Ölçekleme Tamamlandı.\n")


# --- Adım 6: CNN-LSTM Modelini Oluşturma ---
print("Adım 6: CNN-LSTM Hibrid Modeli Oluşturuluyor...")

model = Sequential([
    # 1. 1D-CNN Katmanı: Zaman serisi verisinden özellik çıkarır
    Conv1D(
        filters=64, 
        kernel_size=3, # 3 zaman adımına aynı anda bakar
        activation='relu', 
        input_shape=(TIMESTEPS, FEATURES)
    ),
    Conv1D(filters=64, kernel_size=3, activation='relu'),
    MaxPooling1D(pool_size=2),
    BatchNormalization(),
    Dropout(0.3),
    
    # 2. LSTM Katmanı: Çıkarılan özelliklerin zamansal desenini öğrenir
    LSTM(50, return_sequences=False),
    BatchNormalization(),
    Dropout(0.3),
    
    # 3. Çıkış Katmanı
    Dense(32, activation='relu'),
    Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
print("Model Oluşturma Tamamlandı.\n")

# --- Adım 7: Modeli Eğitme ---
print("Adım 7: Model Eğitimi Başlıyor...")

history = model.fit(
    X_train_scaled, 
    y_train, 
    epochs=60, # Epoch sayısını 50-100 arası deneyebilirsin
    batch_size=16, 
    validation_data=(X_test_scaled, y_test)
)

print("Model Eğitimi Tamamlandı.\n")


# --- Adım 8: Modeli Değerlendirme ---
print("Adım 8: Model Değerlendirmesi...")

# Test verisi üzerindeki loss ve accuracy değerleri
loss, accuracy = model.evaluate(X_test_scaled, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")

# Tahminleri yap
y_pred_probs = model.predict(X_test_scaled)
y_pred = np.argmax(y_pred_probs, axis=1) # Olasılıklardan en yüksek sınıfı seç
y_test_labels = np.argmax(y_test, axis=1) # One-hot'tan normal etikete dön

# Sınıflandırma Raporu (Precision, Recall, F1-score)
print("\nClassification Report:")
print(classification_report(y_test_labels, y_pred, target_names=label_encoder.classes_))

# Karışıklık Matrisi (Confusion Matrix)
print("\nConfusion Matrix:")
cm = confusion_matrix(y_test_labels, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='Blues', 
    xticklabels=label_encoder.classes_, 
    yticklabels=label_encoder.classes_
)
plt.xlabel('Tahmin Edilen (Predicted)')
plt.ylabel('Gerçek (True)')
plt.show()


# --- Adım 9: Modeli ve Gerekli Nesneleri Kaydetme ---
print("\nAdım 9: Model ve diğer nesneler kaydediliyor...")

MODEL_OUTPUT_DIR = f"final_lstm_models_{MOVEMENT_TYPE}"
if not os.path.exists(MODEL_OUTPUT_DIR):
    os.makedirs(MODEL_OUTPUT_DIR)

# 1. Keras modelini kaydet
model.save(os.path.join(MODEL_OUTPUT_DIR, f'{MOVEMENT_TYPE}_lstm_model.h5'))

# 2. Scaler'ı kaydet
with open(os.path.join(MODEL_OUTPUT_DIR, f'{MOVEMENT_TYPE}_scaler.pkl'), 'wb') as f:
    pickle.dump(scaler, f)

# 3. Label Encoder'ı kaydet
with open(os.path.join(MODEL_OUTPUT_DIR, f'{MOVEMENT_TYPE}_label_encoder.pkl'), 'wb') as f:
    pickle.dump(label_encoder, f)

print(f"Tüm dosyalar başarıyla '{MODEL_OUTPUT_DIR}' klasörüne kaydedildi.")
# Out:
# Adım 2: Veri Yükleme ve Ön İşleme Başladı...
# Toplam 300 adet .pkl kaydı yüklendi.
# Adım 3: Tüm veriler 80 adımına eşitleniyor...
# Boyut Eşitleme Tamamlandı.
#
# Adım 4: Veriyi Derin Öğrenme Formatına Dönüştürme Başladı...
# Bulunan sınıflar (4 adet): ['LeaningOppositeSide' 'TooHighAbduction' 'True' 'WrongElbow']
# Veri şekli (X): (300, 80, 40)
# Etiket şekli (y): (300, 4)
# Veri Dönüştürme Tamamlandı.
#
# Adım 5: Veriyi Ayırma ve Ölçekleme Başladı...
# Eğitim verisi: (240, 80, 40), Test verisi: (60, 80, 40)
# Veri Ayırma ve Ölçekleme Tamamlandı.
#
# Adım 6: CNN-LSTM Hibrid Modeli Oluşturuluyor...
# /opt/conda/envs/python313/lib/python3.13/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)               │ (None, 78, 64)         │         7,744 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 76, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 38, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 38, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 38, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        23,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 50)             │           200 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         1,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 45,316 (177.02 KB)
#  Trainable params: 45,088 (176.12 KB)
#  Non-trainable params: 228 (912.00 B)
# Model Oluşturma Tamamlandı.
#
# Adım 7: Model Eğitimi Başlıyor...
# Epoch 1/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.2958 - loss: 1.7019 - val_accuracy: 0.2667 - val_loss: 1.3438
# Epoch 2/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5292 - loss: 1.1221 - val_accuracy: 0.3167 - val_loss: 1.2835
# Epoch 3/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6375 - loss: 0.9090 - val_accuracy: 0.4000 - val_loss: 1.2276
# Epoch 4/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7333 - loss: 0.7249 - val_accuracy: 0.4500 - val_loss: 1.1274
# Epoch 5/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8708 - loss: 0.4873 - val_accuracy: 0.6500 - val_loss: 1.0030
# Epoch 6/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8417 - loss: 0.4360 - val_accuracy: 0.7500 - val_loss: 0.8346
# Epoch 7/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8792 - loss: 0.3465 - val_accuracy: 0.8333 - val_loss: 0.6508
# Epoch 8/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9458 - loss: 0.2631 - val_accuracy: 0.8833 - val_loss: 0.5064
# Epoch 9/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9583 - loss: 0.1720 - val_accuracy: 0.9167 - val_loss: 0.3625
# Epoch 10/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9917 - loss: 0.0905 - val_accuracy: 0.9167 - val_loss: 0.2914
# Epoch 11/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9917 - loss: 0.0867 - val_accuracy: 0.9333 - val_loss: 0.2586
# Epoch 12/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9958 - loss: 0.0516 - val_accuracy: 0.9333 - val_loss: 0.2159
# Epoch 13/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9792 - loss: 0.0706 - val_accuracy: 0.9333 - val_loss: 0.2296
# Epoch 14/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9750 - loss: 0.0694 - val_accuracy: 0.9500 - val_loss: 0.2423
# Epoch 15/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9917 - loss: 0.0374 - val_accuracy: 0.9500 - val_loss: 0.2109
# Epoch 16/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9958 - loss: 0.0318 - val_accuracy: 0.9667 - val_loss: 0.1538
# Epoch 17/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0178 - val_accuracy: 0.9667 - val_loss: 0.1479
# Epoch 18/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9917 - loss: 0.0259 - val_accuracy: 0.9667 - val_loss: 0.1398
# Epoch 19/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9917 - loss: 0.0293 - val_accuracy: 0.9667 - val_loss: 0.1034
# Epoch 20/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9958 - loss: 0.0185 - val_accuracy: 0.9500 - val_loss: 0.2098
# Epoch 21/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9958 - loss: 0.0188 - val_accuracy: 0.9500 - val_loss: 0.2620
# Epoch 22/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.9667 - val_loss: 0.2612
# Epoch 23/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9917 - loss: 0.0227 - val_accuracy: 0.9667 - val_loss: 0.2451
# Epoch 24/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.9667 - val_loss: 0.2232
# Epoch 25/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9875 - loss: 0.0541 - val_accuracy: 0.9833 - val_loss: 0.1672
# Epoch 26/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9958 - loss: 0.0158 - val_accuracy: 0.9667 - val_loss: 0.1920
# Epoch 27/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9958 - loss: 0.0171 - val_accuracy: 0.9833 - val_loss: 0.1683
# Epoch 28/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9917 - loss: 0.0308 - val_accuracy: 0.9833 - val_loss: 0.1638
# Epoch 29/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9750 - loss: 0.1623 - val_accuracy: 0.9667 - val_loss: 0.2029
# Epoch 30/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9875 - loss: 0.0382 - val_accuracy: 0.9833 - val_loss: 0.1532
# Epoch 31/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9875 - loss: 0.0408 - val_accuracy: 0.9667 - val_loss: 0.2773
# Epoch 32/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9750 - loss: 0.0708 - val_accuracy: 0.9667 - val_loss: 0.2611
# Epoch 33/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9958 - loss: 0.0191 - val_accuracy: 0.9667 - val_loss: 0.2705
# Epoch 34/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9958 - loss: 0.0208 - val_accuracy: 0.9667 - val_loss: 0.2765
# Epoch 35/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9875 - loss: 0.0320 - val_accuracy: 0.9500 - val_loss: 0.3036
# Epoch 36/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9958 - loss: 0.0119 - val_accuracy: 0.9500 - val_loss: 0.2574
# Epoch 37/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9667 - val_loss: 0.1811
# Epoch 38/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.9833 - val_loss: 0.1586
# Epoch 39/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9833 - val_loss: 0.1586
# Epoch 40/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9833 - val_loss: 0.1593
# Epoch 41/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9833 - val_loss: 0.1597
# Epoch 42/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9833 - val_loss: 0.1605
# Epoch 43/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9917 - loss: 0.0190 - val_accuracy: 0.9833 - val_loss: 0.1578
# Epoch 44/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9958 - loss: 0.0114 - val_accuracy: 0.9833 - val_loss: 0.1601
# Epoch 45/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9958 - loss: 0.0151 - val_accuracy: 0.9833 - val_loss: 0.1611
# Epoch 46/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9958 - loss: 0.0139 - val_accuracy: 0.9833 - val_loss: 0.1655
# Epoch 47/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9833 - val_loss: 0.1729
# Epoch 48/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9958 - loss: 0.0132 - val_accuracy: 0.9833 - val_loss: 0.1772
# Epoch 49/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9958 - loss: 0.0075 - val_accuracy: 0.9833 - val_loss: 0.1817
# Epoch 50/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9792 - loss: 0.1011 - val_accuracy: 0.9833 - val_loss: 0.1784
# Epoch 51/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9958 - loss: 0.0120 - val_accuracy: 0.9500 - val_loss: 0.3794
# Epoch 52/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9917 - loss: 0.0151 - val_accuracy: 0.9500 - val_loss: 0.4169
# Epoch 53/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9833 - loss: 0.0897 - val_accuracy: 0.9500 - val_loss: 0.3618
# Epoch 54/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9875 - loss: 0.0523 - val_accuracy: 0.9667 - val_loss: 0.3008
# Epoch 55/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9875 - loss: 0.0378 - val_accuracy: 0.9667 - val_loss: 0.3023
# Epoch 56/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9875 - loss: 0.0383 - val_accuracy: 0.9667 - val_loss: 0.2938
# Epoch 57/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9958 - loss: 0.0129 - val_accuracy: 0.9667 - val_loss: 0.3086
# Epoch 58/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9500 - val_loss: 0.3289
# Epoch 59/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9875 - loss: 0.1073 - val_accuracy: 0.9667 - val_loss: 0.3151
# Epoch 60/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9667 - val_loss: 0.3019
# Model Eğitimi Tamamlandı.
#
# Adım 8: Model Değerlendirmesi...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9667 - loss: 0.3019
# Test Accuracy: 96.67%
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# LeaningOppositeSide       0.93      0.93      0.93        15
#    TooHighAbduction       1.00      1.00      1.00        15
#                True       0.94      1.00      0.97        15
#          WrongElbow       1.00      0.93      0.97        15
#
#            accuracy                           0.97        60
#           macro avg       0.97      0.97      0.97        60
#        weighted avg       0.97      0.97      0.97        60
#
#
# Confusion Matrix:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Adım 9: Model ve diğer nesneler kaydediliyor...
# Tüm dosyalar başarıyla 'final_lstm_models_' klasörüne kaydedildi.

# %%
# Adım 1: Gerekli Kütüphaneleri Yükleme
import os
import numpy as np
import pickle
from pyquaternion import Quaternion # Normalizasyon için
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.layers import Conv1D, MaxPooling1D
import matplotlib.pyplot as plt

# --- KONFİGÜRASYON ---
# ... (TÜM KONFİGÜRASYON AYARLARI AYNI) ...
DATA_FOLDER = '' 
MOVEMENT_TYPE = ''
TIMESTEPS = 80
NUM_SENSORS = 10
FEATURES_PER_SENSOR = 4
FEATURES = NUM_SENSORS * FEATURES_PER_SENSOR
USERS_TO_ANALYZE = ["User-A","User-B","User-C", "User-D", "User-E"]

# --- Adım 2.1: Yardımcı Fonksiyonlar ---

def normalize_sequence(sequence_data):
    """
    (N, 40) şeklindeki bir NumPy dizisini ilk karesine göre normalize eder.
    Sıralamanın (w, x, y, z) olduğunu varsayar.
    """
    if not sequence_data.any(): # Tamamen sıfırsa dokunma
        return sequence_data
    
    # 1. İlk kareyi (referans yönelimi) al
    first_frame = sequence_data[0] # (40,) şeklinde
    inverse_references = []
    
    # 2. 10 sensör için de ters (inverse) quaternion'ları hesapla
    for i in range(NUM_SENSORS):
        offset = i * FEATURES_PER_SENSOR
        w, x, y, z = first_frame[offset], first_frame[offset+1], first_frame[offset+2], first_frame[offset+3]
        
        # Olası bir sıfır veriye karşı koruma
        if w == 0 and x == 0 and y == 0 and z == 0:
             q_ref = Quaternion(1, 0, 0, 0) # Nötr (identity) quaternion
        else:
            q_ref = Quaternion(w, x, y, z)
            
        inverse_references.append(q_ref.inverse)
        
    normalized_sequence = []
    
    # 3. Tüm zaman adımlarını (timesteps) bu referanslara göre normalize et
    for frame in sequence_data:
        normalized_frame_features = []
        for i in range(NUM_SENSORS):
            offset = i * FEATURES_PER_SENSOR
            w, x, y, z = frame[offset], frame[offset+1], frame[offset+2], frame[offset+3]
            
            if w == 0 and x == 0 and y == 0 and z == 0:
                q_live = Quaternion(1, 0, 0, 0)
            else:
                q_live = Quaternion(w, x, y, z)
            
            # Referans yönelimi çıkar
            q_normalized = inverse_references[i] * q_live
            
            # Yeni (w,x,y,z) değerlerini düz listeye ekle
            normalized_frame_features.extend([q_normalized.w, q_normalized.x, q_normalized.y, q_normalized.z])
        
        normalized_sequence.append(normalized_frame_features)
        
    return np.array(normalized_sequence)


def augment_data(sequence_data, noise_level=0.01):
    """Veriye rastgele küçük gürültüler (jitter) ekler."""
    noise = np.random.normal(0, noise_level, sequence_data.shape)
    return sequence_data + noise

# --- Adım 2: Veriyi Yükleme ve Ön İşleme ---
print("Adım 2: Veri Yükleme ve Ön İşleme Başladı...")

all_data = []
all_labels = []

movement_path = os.path.join(DATA_FOLDER, MOVEMENT_TYPE)
for user_folder in USERS_TO_ANALYZE:
    user_path = os.path.join(movement_path, user_folder)
    if os.path.isdir(user_path) and user_folder.startswith('User-'):
        for label_folder in os.listdir(user_path):
            label_path = os.path.join(user_path, label_folder)
            if os.path.isdir(label_path):
                for pkl_file in os.listdir(label_path):
                    if pkl_file.endswith('.pkl'):
                        file_path = os.path.join(label_path, pkl_file)
                        try:
                            with open(file_path, 'rb') as f:
                                obj = pickle.load(f)
                            
                            recording_data = np.array(obj['data'])
                            
                            if recording_data.shape[0] < 1 or recording_data.shape[1] != FEATURES:
                                continue
                                
                            recording_data_normalized = normalize_sequence(recording_data)
                            
                            # --- DÜZELTME: Veri artırmayı burada YAPMIYORUZ ---
                            # Sadece orijinal, normalize edilmiş veriyi ekle
                            all_data.append(recording_data_normalized)
                            all_labels.append(label_folder) 
                            
                        except Exception as e:
                            print(f"Hata: {file_path} dosyası okunurken hata oluştu: {e}")

print(f"Toplam {len(all_data)} adet ORİJİNAL .pkl kaydı yüklendi.") # -> 300 olmalı

# --- Adım 3: Boyut Eşitleme (Padding/Trimming) ---
print(f"Adım 3: Tüm veriler {TIMESTEPS} adımına eşitleniyor...")
X_padded = pad_sequences(all_data, maxlen=TIMESTEPS, dtype='float32', padding='post', truncating='post')
print("Boyut Eşitleme Tamamlandı.\n")

# --- Adım 4: Veriyi Derin Öğrenme Formatına Dönüştürme ---
print("Adım 4: Veriyi Derin Öğrenme Formatına Dönüştürme Başladı...")
X = X_padded
y = np.array(all_labels)

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
num_classes = len(label_encoder.classes_)
y_one_hot = to_categorical(y_encoded, num_classes=num_classes)

print(f"Bulunan sınıflar ({num_classes} adet): {label_encoder.classes_}")
print(f"Veri şekli (X): {X.shape}") # -> (300, 80, 40)
print(f"Etiket şekli (y): {y_one_hot.shape}") # -> (300, 4)
print("Veri Dönüştürme Tamamlandı.\n")

# --- Adım 5: Eğitim ve Test Verisi Olarak Ayırma ve ÖLÇEKLEME ---
print("Adım 5: Veriyi Ayırma ve Ölçekleme Başladı...")

X_train, X_test, y_train, y_test = train_test_split(
    X, y_one_hot, 
    test_size=0.2, # %20 test
    random_state=42, 
    stratify=y_one_hot
)

# Scaler'ı SADECE EĞİTİM VERİSİNE GÖRE EĞİT
scaler = StandardScaler()
X_train_reshaped = X_train.reshape(-1, FEATURES)
scaler.fit(X_train_reshaped)

X_train_scaled_reshaped = scaler.transform(X_train_reshaped)
X_test_scaled_reshaped = scaler.transform(X_test.reshape(-1, FEATURES))

X_train_scaled = X_train_scaled_reshaped.reshape(X_train.shape)
X_test_scaled = X_test_scaled_reshaped.reshape(X_test.shape)

print(f"Orijinal Eğitim verisi: {X_train_scaled.shape}, Test verisi: {X_test_scaled.shape}")
print("Veri Ayırma ve Ölçekleme Tamamlandı.\n")

# --- YENİ ADIM: Veri Artırmayı SADECE EĞİTİM SETİNE UYGULA ---
print("Adım 5.5: Veri Artırma (Augmentation) SADECE Eğitim Verisine Uygulanıyor...")
X_train_augmented = []
y_train_augmented = []

for i in range(len(X_train_scaled)):
    sequence = X_train_scaled[i]
    label = y_train[i]
    
    # 1. Orijinal veriyi ekle
    X_train_augmented.append(sequence)
    y_train_augmented.append(label)
    
    # 2. İki adet gürültü eklenmiş kopya ekle
    X_train_augmented.append(augment_data(sequence, 0.01))
    y_train_augmented.append(label)
    
    X_train_augmented.append(augment_data(sequence, 0.005))
    y_train_augmented.append(label)

X_train_final = np.array(X_train_augmented)
y_train_final = np.array(y_train_augmented)

print(f"Artırılmış yeni eğitim verisi şekli: {X_train_final.shape}") # -> (720, 80, 40)
print(f"Test verisi şekli (DEĞİŞMEDİ): {X_test_scaled.shape}") # -> (60, 80, 40)
print("Veri Artırma Tamamlandı.\n")


# --- Adım 6: CNN-LSTM Modelini Oluşturma ---
print("Adım 6: CNN-LSTM Hibrid Modeli Oluşturuluyor...")
model = Sequential([
    # 1. 1D-CNN Katmanı: Zaman serisi verisinden özellik çıkarır
    Conv1D(
        filters=64, 
        kernel_size=3, # 3 zaman adımına aynı anda bakar
        activation='relu', 
        input_shape=(TIMESTEPS, FEATURES)
    ),
    Conv1D(filters=64, kernel_size=3, activation='relu'),
    MaxPooling1D(pool_size=2),
    BatchNormalization(),
    Dropout(0.3),
    
    # 2. LSTM Katmanı: Çıkarılan özelliklerin zamansal desenini öğrenir
    LSTM(50, return_sequences=False),
    BatchNormalization(),
    Dropout(0.3),
    
    # 3. Çıkış Katmanı
    Dense(32, activation='relu'),
    Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
print("Model Oluşturma Tamamlandı.\n")


# --- Adım 7: Modeli Eğitme ---
print("Adım 7: Model Eğitimi Başlıyor...")

history = model.fit(
    X_train_final, # <-- Artırılmış eğitim verisini kullan
    y_train_final, 
    epochs=60,
    batch_size=16, 
    validation_data=(X_test_scaled, y_test) # <-- Orijinal, el değmemiş test verisini kullan
)
# ... (Kodun geri kalanı aynı) ...

print("Model Eğitimi Tamamlandı.\n")


# --- Adım 8: Modeli Değerlendirme ---
print("Adım 8: Model Değerlendirmesi...")

# Test verisi üzerindeki loss ve accuracy değerleri
loss, accuracy = model.evaluate(X_test_scaled, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")

# Tahminleri yap
y_pred_probs = model.predict(X_test_scaled)
y_pred = np.argmax(y_pred_probs, axis=1) # Olasılıklardan en yüksek sınıfı seç
y_test_labels = np.argmax(y_test, axis=1) # One-hot'tan normal etikete dön

# Sınıflandırma Raporu (Precision, Recall, F1-score)
print("\nClassification Report:")
print(classification_report(y_test_labels, y_pred, target_names=label_encoder.classes_))

# Karışıklık Matrisi (Confusion Matrix)
print("\nConfusion Matrix:")
cm = confusion_matrix(y_test_labels, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='Blues', 
    xticklabels=label_encoder.classes_, 
    yticklabels=label_encoder.classes_
)
plt.xlabel('Tahmin Edilen (Predicted)')
plt.ylabel('Gerçek (True)')
plt.show()


# --- Adım 9: Modeli ve Gerekli Nesneleri Kaydetme ---
print("\nAdım 9: Model ve diğer nesneler kaydediliyor...")

MODEL_OUTPUT_DIR = f"final_lstm_models_{MOVEMENT_TYPE}"
if not os.path.exists(MODEL_OUTPUT_DIR):
    os.makedirs(MODEL_OUTPUT_DIR)

# 1. Keras modelini kaydet
model.save(os.path.join(MODEL_OUTPUT_DIR, f'{MOVEMENT_TYPE}_lstm_model.h5'))

# 2. Scaler'ı kaydet
with open(os.path.join(MODEL_OUTPUT_DIR, f'{MOVEMENT_TYPE}_scaler.pkl'), 'wb') as f:
    pickle.dump(scaler, f)

# 3. Label Encoder'ı kaydet
with open(os.path.join(MODEL_OUTPUT_DIR, f'{MOVEMENT_TYPE}_label_encoder.pkl'), 'wb') as f:
    pickle.dump(label_encoder, f)

print(f"Tüm dosyalar başarıyla '{MODEL_OUTPUT_DIR}' klasörüne kaydedildi.")
# Out:
# Adım 2: Veri Yükleme ve Ön İşleme Başladı...
# Toplam 300 adet ORİJİNAL .pkl kaydı yüklendi.
# Adım 3: Tüm veriler 80 adımına eşitleniyor...
# Boyut Eşitleme Tamamlandı.
#
# Adım 4: Veriyi Derin Öğrenme Formatına Dönüştürme Başladı...
# Bulunan sınıflar (4 adet): ['LeaningOppositeSide' 'TooHighAbduction' 'True' 'WrongElbow']
# Veri şekli (X): (300, 80, 40)
# Etiket şekli (y): (300, 4)
# Veri Dönüştürme Tamamlandı.
#
# Adım 5: Veriyi Ayırma ve Ölçekleme Başladı...
# Orijinal Eğitim verisi: (240, 80, 40), Test verisi: (60, 80, 40)
# Veri Ayırma ve Ölçekleme Tamamlandı.
#
# Adım 5.5: Veri Artırma (Augmentation) SADECE Eğitim Verisine Uygulanıyor...
# Artırılmış yeni eğitim verisi şekli: (720, 80, 40)
# Test verisi şekli (DEĞİŞMEDİ): (60, 80, 40)
# Veri Artırma Tamamlandı.
#
# Adım 6: CNN-LSTM Hibrid Modeli Oluşturuluyor...
# /opt/conda/envs/python313/lib/python3.13/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_4 (Conv1D)               │ (None, 78, 64)         │         7,744 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 76, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 38, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 38, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 38, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 50)             │        23,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 50)             │           200 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         1,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 45,316 (177.02 KB)
#  Trainable params: 45,088 (176.12 KB)
#  Non-trainable params: 228 (912.00 B)
# Model Oluşturma Tamamlandı.
#
# Adım 7: Model Eğitimi Başlıyor...
# Epoch 1/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.5625 - loss: 1.0375 - val_accuracy: 0.5000 - val_loss: 1.1589
# Epoch 2/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9139 - loss: 0.3340 - val_accuracy: 0.8333 - val_loss: 0.7383
# Epoch 3/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9750 - loss: 0.1254 - val_accuracy: 0.9333 - val_loss: 0.3505
# Epoch 4/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9847 - loss: 0.0685 - val_accuracy: 0.9500 - val_loss: 0.1900
# Epoch 5/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9889 - loss: 0.0475 - val_accuracy: 0.9500 - val_loss: 0.2041
# Epoch 6/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9944 - loss: 0.0317 - val_accuracy: 0.9500 - val_loss: 0.1809
# Epoch 7/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9917 - loss: 0.0274 - val_accuracy: 0.9667 - val_loss: 0.2122
# Epoch 8/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9958 - loss: 0.0279 - val_accuracy: 0.9667 - val_loss: 0.1887
# Epoch 9/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9861 - loss: 0.0620 - val_accuracy: 0.9667 - val_loss: 0.1817
# Epoch 10/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9986 - loss: 0.0110 - val_accuracy: 0.9500 - val_loss: 0.1870
# Epoch 11/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.9667 - val_loss: 0.1745
# Epoch 12/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9667 - val_loss: 0.2213
# Epoch 13/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9986 - loss: 0.0113 - val_accuracy: 0.9667 - val_loss: 0.2554
# Epoch 14/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9931 - loss: 0.0203 - val_accuracy: 0.9500 - val_loss: 0.2553
# Epoch 15/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9903 - loss: 0.0487 - val_accuracy: 0.9667 - val_loss: 0.2250
# Epoch 16/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9778 - loss: 0.0729 - val_accuracy: 0.9667 - val_loss: 0.2222
# Epoch 17/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9889 - loss: 0.0583 - val_accuracy: 0.9500 - val_loss: 0.3543
# Epoch 18/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9903 - loss: 0.0257 - val_accuracy: 0.9667 - val_loss: 0.2341
# Epoch 19/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9986 - loss: 0.0096 - val_accuracy: 0.9667 - val_loss: 0.2160
# Epoch 20/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9944 - loss: 0.0232 - val_accuracy: 0.9667 - val_loss: 0.2237
# Epoch 21/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9917 - loss: 0.0273 - val_accuracy: 0.9667 - val_loss: 0.2205
# Epoch 22/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9917 - loss: 0.0218 - val_accuracy: 0.9667 - val_loss: 0.2022
# Epoch 23/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9972 - loss: 0.0079 - val_accuracy: 0.9833 - val_loss: 0.1385
# Epoch 24/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9833 - val_loss: 0.1468
# Epoch 25/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9833 - val_loss: 0.1538
# Epoch 26/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9833 - val_loss: 0.1568
# Epoch 27/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9972 - loss: 0.0086 - val_accuracy: 0.9667 - val_loss: 0.2831
# Epoch 28/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9986 - loss: 0.0052 - val_accuracy: 0.9500 - val_loss: 0.3202
# Epoch 29/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9944 - loss: 0.0238 - val_accuracy: 0.9667 - val_loss: 0.2848
# Epoch 30/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9986 - loss: 0.0035 - val_accuracy: 0.9667 - val_loss: 0.2703
# Epoch 31/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9986 - loss: 0.0051 - val_accuracy: 0.9667 - val_loss: 0.2748
# Epoch 32/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9667 - val_loss: 0.2834
# Epoch 33/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 8.0379e-04 - val_accuracy: 0.9667 - val_loss: 0.2851
# Epoch 34/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9667 - val_loss: 0.2986
# Epoch 35/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 7.2156e-04 - val_accuracy: 0.9667 - val_loss: 0.3034
# Epoch 36/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9667 - val_loss: 0.2838
# Epoch 37/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9667 - val_loss: 0.2847
# Epoch 38/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 8.1094e-04 - val_accuracy: 0.9667 - val_loss: 0.2900
# Epoch 39/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 9.9242e-04 - val_accuracy: 0.9667 - val_loss: 0.2763
# Epoch 40/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9986 - loss: 0.0027 - val_accuracy: 0.9667 - val_loss: 0.2930
# Epoch 41/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 5.9864e-04 - val_accuracy: 0.9667 - val_loss: 0.2972
# Epoch 42/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 4.2185e-04 - val_accuracy: 0.9667 - val_loss: 0.2970
# Epoch 43/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9667 - val_loss: 0.2949
# Epoch 44/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 5.6504e-04 - val_accuracy: 0.9667 - val_loss: 0.2998
# Epoch 45/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 4.4720e-04 - val_accuracy: 0.9667 - val_loss: 0.3065
# Epoch 46/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 4.1059e-04 - val_accuracy: 0.9667 - val_loss: 0.2806
# Epoch 47/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 4.4625e-04 - val_accuracy: 0.9667 - val_loss: 0.2881
# Epoch 48/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9667 - val_loss: 0.4284
# Epoch 49/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9944 - loss: 0.0677 - val_accuracy: 0.9667 - val_loss: 0.3810
# Epoch 50/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9667 - val_loss: 0.3763
# Epoch 51/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9903 - loss: 0.0429 - val_accuracy: 0.9833 - val_loss: 0.1276
# Epoch 52/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9931 - loss: 0.0210 - val_accuracy: 0.9667 - val_loss: 0.1713
# Epoch 53/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9944 - loss: 0.0276 - val_accuracy: 0.9667 - val_loss: 0.3860
# Epoch 54/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9944 - loss: 0.0191 - val_accuracy: 0.9667 - val_loss: 0.3895
# Epoch 55/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9917 - loss: 0.0241 - val_accuracy: 0.9667 - val_loss: 0.2873
# Epoch 56/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9917 - loss: 0.0472 - val_accuracy: 0.9500 - val_loss: 0.4444
# Epoch 57/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9958 - loss: 0.0263 - val_accuracy: 0.9667 - val_loss: 0.2465
# Epoch 58/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9667 - val_loss: 0.2263
# Epoch 59/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9986 - loss: 0.0054 - val_accuracy: 0.9833 - val_loss: 0.1528
# Epoch 60/60
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9833 - val_loss: 0.1568
# Model Eğitimi Tamamlandı.
#
# Adım 8: Model Değerlendirmesi...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9833 - loss: 0.1568
# Test Accuracy: 98.33%
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fb97c64e0c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fb97c64e0c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/stepWARNING:tensorflow:6 out of the last 10 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fb97c64e0c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 10 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fb97c64e0c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# LeaningOppositeSide       1.00      0.93      0.97        15
#    TooHighAbduction       1.00      1.00      1.00        15
#                True       0.94      1.00      0.97        15
#          WrongElbow       1.00      1.00      1.00        15
#
#            accuracy                           0.98        60
#           macro avg       0.98      0.98      0.98        60
#        weighted avg       0.98      0.98      0.98        60
#
#
# Confusion Matrix:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Adım 9: Model ve diğer nesneler kaydediliyor...
# Tüm dosyalar başarıyla 'final_lstm_models_' klasörüne kaydedildi.

# %%
# Adım 1: Gerekli Kütüphaneleri Yükleme
import os
import numpy as np
import pickle
from pyquaternion import Quaternion # Normalizasyon için
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.layers import GRU # <-- Değiştir
import matplotlib.pyplot as plt

# --- KONFİGÜRASYON ---
# Verinin bulunduğu ana klasör
DATA_FOLDER = '' 
# Hangi hareketi eğitmek istiyoruz?
MOVEMENT_TYPE = ''
# Tüm zaman serilerini eşitleyeceğimiz uzunluk (gördüğümüz 80-82'ye göre 80 ideal)
TIMESTEPS = 80
NUM_SENSORS = 10
FEATURES_PER_SENSOR = 4 # w, x, y, z
FEATURES = NUM_SENSORS * FEATURES_PER_SENSOR # Toplam 40 özellik
USERS_TO_ANALYZE = ["User-A","User-B","User-C", "User-D", "User-E"]


# --- Adım 2.1: Normalizasyon için Yardımcı Fonksiyon ---

def normalize_sequence(sequence_data):
    """
    (N, 40) şeklindeki bir NumPy dizisini ilk karesine göre normalize eder.
    Sıralamanın (w, x, y, z) olduğunu varsayar.
    """
    if not sequence_data.any(): # Tamamen sıfırsa dokunma
        return sequence_data
    
    # 1. İlk kareyi (referans yönelimi) al
    first_frame = sequence_data[0] # (40,) şeklinde
    inverse_references = []
    
    # 2. 10 sensör için de ters (inverse) quaternion'ları hesapla
    for i in range(NUM_SENSORS):
        offset = i * FEATURES_PER_SENSOR
        w, x, y, z = first_frame[offset], first_frame[offset+1], first_frame[offset+2], first_frame[offset+3]
        
        # Olası bir sıfır veriye karşı koruma
        if w == 0 and x == 0 and y == 0 and z == 0:
             q_ref = Quaternion(1, 0, 0, 0) # Nötr (identity) quaternion
        else:
            q_ref = Quaternion(w, x, y, z)
            
        inverse_references.append(q_ref.inverse)
        
    normalized_sequence = []
    
    # 3. Tüm zaman adımlarını (timesteps) bu referanslara göre normalize et
    for frame in sequence_data:
        normalized_frame_features = []
        for i in range(NUM_SENSORS):
            offset = i * FEATURES_PER_SENSOR
            w, x, y, z = frame[offset], frame[offset+1], frame[offset+2], frame[offset+3]
            
            if w == 0 and x == 0 and y == 0 and z == 0:
                q_live = Quaternion(1, 0, 0, 0)
            else:
                q_live = Quaternion(w, x, y, z)
            
            # Referans yönelimi çıkar
            q_normalized = inverse_references[i] * q_live
            
            # Yeni (w,x,y,z) değerlerini düz listeye ekle
            normalized_frame_features.extend([q_normalized.w, q_normalized.x, q_normalized.y, q_normalized.z])
        
        normalized_sequence.append(normalized_frame_features)
        
    return np.array(normalized_sequence)


# --- Adım 2: Veriyi Yükleme ve Ön İşleme ---
print("Adım 2: Veri Yükleme ve Ön İşleme Başladı...")

all_data = []
all_labels = []

movement_path = os.path.join(DATA_FOLDER, MOVEMENT_TYPE)
# User-A, User-B, ... klasörlerinde gezin
for user_folder in USERS_TO_ANALYZE:
    user_path = os.path.join(movement_path, user_folder)
    if os.path.isdir(user_path) and user_folder.startswith('User-'):

        # True, WrongElbow, ... klasörlerinde gezin
        for label_folder in os.listdir(user_path):
            label_path = os.path.join(user_path, label_folder)
            if os.path.isdir(label_path):

                # .pkl dosyalarını oku
                for pkl_file in os.listdir(label_path):
                    if pkl_file.endswith('.pkl'):
                        file_path = os.path.join(label_path, pkl_file)

                        try:
                            with open(file_path, 'rb') as f:
                                obj = pickle.load(f)

                            # .pkl içindeki 'data' anahtarından veriyi al
                            recording_data = np.array(obj['data'])

                            # Veri geçerli mi diye kontrol et (en az 1 frame olmalı)
                            if recording_data.shape[0] < 1 or recording_data.shape[1] != FEATURES:
                                print(f"Uyarı: Hatalı veri atlanıyor (şekil {recording_data.shape}): {file_path}")
                                continue

                            # --- YENİ: Normalizasyon ---
                            recording_data_normalized = normalize_sequence(recording_data)

                            all_data.append(recording_data_normalized)
                            all_labels.append(label_folder) # Etiket olarak klasör adını kullan

                        except Exception as e:
                            print(f"Hata: {file_path} dosyası okunurken hata oluştu: {e}")

print(f"Toplam {len(all_data)} adet .pkl kaydı yüklendi.")

# --- Adım 3: Boyut Eşitleme (Padding/Trimming) ---
print(f"Adım 3: Tüm veriler {TIMESTEPS} adımına eşitleniyor...")

# Keras'ın 'pad_sequences' fonksiyonunu kullanalım. Çok daha verimli.
# 'post' = eksik veriyi sona ekle/sondan kırp
X_padded = pad_sequences(
    all_data, 
    maxlen=TIMESTEPS, 
    dtype='float32', 
    padding='post', 
    truncating='post'
)

print("Boyut Eşitleme Tamamlandı.\n")


# --- Adım 4: Veriyi Derin Öğrenme Formatına Dönüştürme ---
print("Adım 4: Veriyi Derin Öğrenme Formatına Dönüştürme Başladı...")

X = X_padded # Artık tüm verilerimiz (sample_sayısı, 80, 40) şeklinde
y = np.array(all_labels)

# Etiketleri sayısal değerlere çevir (örn: 'Correct' -> 0, 'WrongElbow' -> 1)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Sınıf sayısını al
num_classes = len(label_encoder.classes_)
print(f"Bulunan sınıflar ({num_classes} adet): {label_encoder.classes_}")

# Sayısal etiketleri one-hot encoding formatına çevir
# Örn: 3 sınıf varsa, 1 -> [0, 1, 0]
y_one_hot = to_categorical(y_encoded, num_classes=num_classes)

print(f"Veri şekli (X): {X.shape}")
print(f"Etiket şekli (y): {y_one_hot.shape}")
print("Veri Dönüştürme Tamamlandı.\n")


# --- Adım 5: Eğitim ve Test Verisi Olarak Ayırma ve Ölçekleme ---
print("Adım 5: Veriyi Ayırma ve Ölçekleme Başladı...")

X_train, X_test, y_train, y_test = train_test_split(
    X, y_one_hot, 
    test_size=0.2,       # Verinin %20'sini test için ayır
    random_state=42,     # Tekrarlanabilir sonuçlar için
    stratify=y_one_hot   # Sınıf dağılımını koru (çok önemli)
)

# Ölçekleme (Scaling) için veriyi 2D'ye çevirmemiz gerekiyor
# (sample_sayısı, 80, 40) -> (sample_sayısı * 80, 40)
scaler = StandardScaler()
X_train_reshaped = X_train.reshape(-1, FEATURES)
scaler.fit(X_train_reshaped)

X_train_scaled_reshaped = scaler.transform(X_train_reshaped)
X_test_scaled_reshaped = scaler.transform(X_test.reshape(-1, FEATURES))

# Veriyi tekrar 3D (LSTM formatı) haline getirelim
X_train_scaled = X_train_scaled_reshaped.reshape(X_train.shape)
X_test_scaled = X_test_scaled_reshaped.reshape(X_test.shape)

print(f"Eğitim verisi: {X_train_scaled.shape}, Test verisi: {X_test_scaled.shape}")
print("Veri Ayırma ve Ölçekleme Tamamlandı.\n")


# --- Adım 6: LSTM Modelini Oluşturma ---
print("Adım 6: LSTM Modeli Oluşturuluyor...")

model = Sequential([
    # Input katmanı: (80, 40) şeklinde veri alacak
    GRU(64, input_shape=(TIMESTEPS, FEATURES), return_sequences=True),
    BatchNormalization(), # Katmanlar arası normalizasyon, öğrenmeyi hızlandırır
    Dropout(0.3),
    
    GRU(32, return_sequences=False), # Son LSTM katmanı, sadece son çıktıyı verir
    BatchNormalization(),
    Dropout(0.3),
    
    Dense(32, activation='relu'),
    
    # Çıkış katmanı: Sınıf sayısı kadar nöron ve 'softmax' aktivasyonu
    Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
print("Model Oluşturma Tamamlandı.\n")


# --- Adım 7: Modeli Eğitme ---
print("Adım 7: Model Eğitimi Başlıyor...")

history = model.fit(
    X_train_scaled, 
    y_train, 
    epochs=60, # Epoch sayısını 50-100 arası deneyebilirsin
    batch_size=16, 
    validation_data=(X_test_scaled, y_test)
)

print("Model Eğitimi Tamamlandı.\n")


# --- Adım 8: Modeli Değerlendirme ---
print("Adım 8: Model Değerlendirmesi...")

# Test verisi üzerindeki loss ve accuracy değerleri
loss, accuracy = model.evaluate(X_test_scaled, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")

# Tahminleri yap
y_pred_probs = model.predict(X_test_scaled)
y_pred = np.argmax(y_pred_probs, axis=1) # Olasılıklardan en yüksek sınıfı seç
y_test_labels = np.argmax(y_test, axis=1) # One-hot'tan normal etikete dön

# Sınıflandırma Raporu (Precision, Recall, F1-score)
print("\nClassification Report:")
print(classification_report(y_test_labels, y_pred, target_names=label_encoder.classes_))

# Karışıklık Matrisi (Confusion Matrix)
print("\nConfusion Matrix:")
cm = confusion_matrix(y_test_labels, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='Blues', 
    xticklabels=label_encoder.classes_, 
    yticklabels=label_encoder.classes_
)
plt.xlabel('Tahmin Edilen (Predicted)')
plt.ylabel('Gerçek (True)')
plt.show()


# --- Adım 9: Modeli ve Gerekli Nesneleri Kaydetme ---
print("\nAdım 9: Model ve diğer nesneler kaydediliyor...")

MODEL_OUTPUT_DIR = f"final_lstm_models_{MOVEMENT_TYPE}"
if not os.path.exists(MODEL_OUTPUT_DIR):
    os.makedirs(MODEL_OUTPUT_DIR)

# 1. Keras modelini kaydet
model.save(os.path.join(MODEL_OUTPUT_DIR, f'{MOVEMENT_TYPE}_lstm_model.h5'))

# 2. Scaler'ı kaydet
with open(os.path.join(MODEL_OUTPUT_DIR, f'{MOVEMENT_TYPE}_scaler.pkl'), 'wb') as f:
    pickle.dump(scaler, f)

# 3. Label Encoder'ı kaydet
with open(os.path.join(MODEL_OUTPUT_DIR, f'{MOVEMENT_TYPE}_label_encoder.pkl'), 'wb') as f:
    pickle.dump(label_encoder, f)

print(f"Tüm dosyalar başarıyla '{MODEL_OUTPUT_DIR}' klasörüne kaydedildi.")
# Out:
# Adım 2: Veri Yükleme ve Ön İşleme Başladı...
# Toplam 300 adet .pkl kaydı yüklendi.
# Adım 3: Tüm veriler 80 adımına eşitleniyor...
# Boyut Eşitleme Tamamlandı.
#
# Adım 4: Veriyi Derin Öğrenme Formatına Dönüştürme Başladı...
# Bulunan sınıflar (4 adet): ['LeaningOppositeSide' 'TooHighAbduction' 'True' 'WrongElbow']
# Veri şekli (X): (300, 80, 40)
# Etiket şekli (y): (300, 4)
# Veri Dönüştürme Tamamlandı.
#
# Adım 5: Veriyi Ayırma ve Ölçekleme Başladı...
# Eğitim verisi: (240, 80, 40), Test verisi: (60, 80, 40)
# Veri Ayırma ve Ölçekleme Tamamlandı.
#
# Adım 6: LSTM Modeli Oluşturuluyor...
# /opt/conda/envs/python313/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_2 (GRU)                     │ (None, 80, 64)         │        20,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 80, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 80, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 32)             │         9,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,332 (122.39 KB)
#  Trainable params: 31,140 (121.64 KB)
#  Non-trainable params: 192 (768.00 B)
# Model Oluşturma Tamamlandı.
#
# Adım 7: Model Eğitimi Başlıyor...
# Epoch 1/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.2667 - loss: 1.5758 - val_accuracy: 0.3833 - val_loss: 1.3316
# Epoch 2/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.4375 - loss: 1.2561 - val_accuracy: 0.4667 - val_loss: 1.2838
# Epoch 3/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.4708 - loss: 1.1841 - val_accuracy: 0.5000 - val_loss: 1.2538
# Epoch 4/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.4875 - loss: 1.1128 - val_accuracy: 0.4667 - val_loss: 1.2175
# Epoch 5/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5333 - loss: 1.0179 - val_accuracy: 0.5667 - val_loss: 1.1405
# Epoch 6/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6125 - loss: 0.9405 - val_accuracy: 0.6333 - val_loss: 1.0741
# Epoch 7/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6958 - loss: 0.7680 - val_accuracy: 0.6000 - val_loss: 1.0162
# Epoch 8/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.7125 - loss: 0.7365 - val_accuracy: 0.6167 - val_loss: 0.9705
# Epoch 9/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7500 - loss: 0.6395 - val_accuracy: 0.6667 - val_loss: 0.8840
# Epoch 10/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.7875 - loss: 0.5462 - val_accuracy: 0.7167 - val_loss: 0.8036
# Epoch 11/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8292 - loss: 0.5088 - val_accuracy: 0.6833 - val_loss: 0.7466
# Epoch 12/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9042 - loss: 0.3929 - val_accuracy: 0.8000 - val_loss: 0.6381
# Epoch 13/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9000 - loss: 0.3721 - val_accuracy: 0.8000 - val_loss: 0.5978
# Epoch 14/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9292 - loss: 0.2785 - val_accuracy: 0.8333 - val_loss: 0.6748
# Epoch 15/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9167 - loss: 0.2138 - val_accuracy: 0.8167 - val_loss: 0.5994
# Epoch 16/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9500 - loss: 0.1938 - val_accuracy: 0.8667 - val_loss: 0.5151
# Epoch 17/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9708 - loss: 0.1429 - val_accuracy: 0.8667 - val_loss: 0.5159
# Epoch 18/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9750 - loss: 0.1077 - val_accuracy: 0.8833 - val_loss: 0.5128
# Epoch 19/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9792 - loss: 0.0930 - val_accuracy: 0.9167 - val_loss: 0.4522
# Epoch 20/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9833 - loss: 0.0895 - val_accuracy: 0.9333 - val_loss: 0.4088
# Epoch 21/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9958 - loss: 0.0527 - val_accuracy: 0.9333 - val_loss: 0.4041
# Epoch 22/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9875 - loss: 0.0495 - val_accuracy: 0.9500 - val_loss: 0.3669
# Epoch 23/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9875 - loss: 0.0401 - val_accuracy: 0.9333 - val_loss: 0.3609
# Epoch 24/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9958 - loss: 0.0375 - val_accuracy: 0.9333 - val_loss: 0.3778
# Epoch 25/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9917 - loss: 0.0331 - val_accuracy: 0.9333 - val_loss: 0.3548
# Epoch 26/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0288 - val_accuracy: 0.9333 - val_loss: 0.4234
# Epoch 27/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9958 - loss: 0.0283 - val_accuracy: 0.9333 - val_loss: 0.3860
# Epoch 28/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0284 - val_accuracy: 0.9500 - val_loss: 0.3933
# Epoch 29/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0152 - val_accuracy: 0.9500 - val_loss: 0.3906
# Epoch 30/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0153 - val_accuracy: 0.9500 - val_loss: 0.3896
# Epoch 31/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0174 - val_accuracy: 0.9500 - val_loss: 0.3891
# Epoch 32/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0136 - val_accuracy: 0.9500 - val_loss: 0.3892
# Epoch 33/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.9500 - val_loss: 0.3894
# Epoch 34/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.9500 - val_loss: 0.3890
# Epoch 35/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 0.9500 - val_loss: 0.3870
# Epoch 36/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 0.9500 - val_loss: 0.3878
# Epoch 37/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.9500 - val_loss: 0.3906
# Epoch 38/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.9500 - val_loss: 0.3936
# Epoch 39/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 0.9500 - val_loss: 0.3956
# Epoch 40/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.9500 - val_loss: 0.3957
# Epoch 41/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.9500 - val_loss: 0.3953
# Epoch 42/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.9500 - val_loss: 0.3954
# Epoch 43/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.9500 - val_loss: 0.3956
# Epoch 44/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9500 - val_loss: 0.3960
# Epoch 45/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.9500 - val_loss: 0.3995
# Epoch 46/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.9500 - val_loss: 0.4058
# Epoch 47/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9500 - val_loss: 0.4090
# Epoch 48/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9500 - val_loss: 0.4123
# Epoch 49/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.9500 - val_loss: 0.4164
# Epoch 50/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9500 - val_loss: 0.4216
# Epoch 51/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9500 - val_loss: 0.4241
# Epoch 52/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9500 - val_loss: 0.4271
# Epoch 53/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.9500 - val_loss: 0.4307
# Epoch 54/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9500 - val_loss: 0.4344
# Epoch 55/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9500 - val_loss: 0.4356
# Epoch 56/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9500 - val_loss: 0.4235
# Epoch 57/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9958 - loss: 0.0077 - val_accuracy: 0.9500 - val_loss: 0.3971
# Epoch 58/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9500 - val_loss: 0.3780
# Epoch 59/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9500 - val_loss: 0.3754
# Epoch 60/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9500 - val_loss: 0.3757
# Model Eğitimi Tamamlandı.
#
# Adım 8: Model Değerlendirmesi...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9500 - loss: 0.3757
# Test Accuracy: 95.00%
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 371ms/step
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# LeaningOppositeSide       0.93      0.87      0.90        15
#    TooHighAbduction       0.94      1.00      0.97        15
#                True       1.00      1.00      1.00        15
#          WrongElbow       0.93      0.93      0.93        15
#
#            accuracy                           0.95        60
#           macro avg       0.95      0.95      0.95        60
#        weighted avg       0.95      0.95      0.95        60
#
#
# Confusion Matrix:
# Adım 9: Model ve diğer nesneler kaydediliyor...
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Tüm dosyalar başarıyla 'final_lstm_models_' klasörüne kaydedildi.

# %%
# Adım 1: Gerekli Kütüphaneleri Yükleme
import os
import numpy as np
import pickle
from pyquaternion import Quaternion # Normalizasyon için
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import classification_report, accuracy_score
import copy # Scaler'ı kopyalamak için

# --- KONFİGÜRASYON ---
DATA_FOLDER = '' 
MOVEMENT_TYPE = '' # Test etmek istediğin hareket
TIMESTEPS = 80 # Veri setindeki (80, 40) şekline göre
NUM_SENSORS = 10
FEATURES_PER_SENSOR = 4 # w, x, y, z
FEATURES = NUM_SENSORS * FEATURES_PER_SENSOR
USERS_TO_ANALYZE = ["User-A", "User-B", "User-C", "User-D", "User-E"] # Analiz edilecek kullanıcılar

# --- Adım 2: Yardımcı Fonksiyonlar ---

def normalize_sequence(sequence_data):
    """
    (N, 40) şeklindeki bir NumPy dizisini ilk karesine göre normalize eder.
    PKL verisinin (w0, x0, y0, z0, ...) sırasıyla geldiğini varsayarak.
    """
    if not sequence_data.any():
        return sequence_data
    
    first_frame = sequence_data[0]
    inverse_references = []
    
    for i in range(NUM_SENSORS):
        offset = i * FEATURES_PER_SENSOR
        w, x, y, z = first_frame[offset], first_frame[offset+1], first_frame[offset+2], first_frame[offset+3]
        
        if w == 0 and x == 0 and y == 0 and z == 0:
             q_ref = Quaternion(1, 0, 0, 0)
        else:
            q_ref = Quaternion(w, x, y, z)
            
        inverse_references.append(q_ref.inverse)
        
    normalized_sequence = []
    
    for frame in sequence_data:
        normalized_frame_features = []
        for i in range(NUM_SENSORS):
            offset = i * FEATURES_PER_SENSOR
            w, x, y, z = frame[offset], frame[offset+1], frame[offset+2], frame[offset+3]
            
            if w == 0 and x == 0 and y == 0 and z == 0:
                q_live = Quaternion(1, 0, 0, 0)
            else:
                q_live = Quaternion(w, x, y, z)
            
            q_normalized = inverse_references[i] * q_live
            normalized_frame_features.extend([q_normalized.w, q_normalized.x, q_normalized.y, q_normalized.z])
        
        normalized_sequence.append(normalized_frame_features)
        
    return np.array(normalized_sequence)

def build_model(num_classes):
    """
    Her döngüde yeniden, taze bir model oluşturmak için fonksiyon.
    """
    model = Sequential([
        GRU(64, input_shape=(TIMESTEPS, FEATURES), return_sequences=True),
        BatchNormalization(),
        Dropout(0.3),
        GRU(32, return_sequences=False),
        BatchNormalization(),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# --- Adım 3: Veriyi Kullanıcılara Göre Yükleme ---
print("Adım 3: Veri Kullanıcılara Göre Yükleniyor...")

# Veriyi { 'User-A': {'data': [...], 'labels': [...]}, ... } şeklinde saklayalım
data_by_user = {}
all_labels_flat = [] # Tüm etiketleri toplamak için

movement_path = os.path.join(DATA_FOLDER, MOVEMENT_TYPE)

for user_folder in USERS_TO_ANALYZE:
    user_path = os.path.join(movement_path, user_folder)
    if not os.path.isdir(user_path):
        print(f"Uyarı: Kullanıcı klasörü atlanıyor (bulunamadı): {user_path}")
        continue

    print(f"Kullanıcı yükleniyor: {user_folder}")
    data_by_user[user_folder] = {'data': [], 'labels': []}

    for label_folder in os.listdir(user_path):
        label_path = os.path.join(user_path, label_folder)
        if os.path.isdir(label_path):
            for pkl_file in os.listdir(label_path):
                if pkl_file.endswith('.pkl'):
                    file_path = os.path.join(label_path, pkl_file)
                    try:
                        with open(file_path, 'rb') as f:
                            obj = pickle.load(f)

                        recording_data = np.array(obj['data'])

                        if recording_data.shape[0] < 1 or recording_data.shape[1] != FEATURES:
                            continue

                        recording_data_normalized = normalize_sequence(recording_data)

                        data_by_user[user_folder]['data'].append(recording_data_normalized)
                        data_by_user[user_folder]['labels'].append(label_folder)
                        all_labels_flat.append(label_folder)

                    except Exception as e:
                        print(f"Hata: {file_path} dosyası okunurken hata oluştu: {e}")

print("Veri Yükleme Tamamlandı.\n")


# --- Adım 4: Etiket Kodlayıcıyı (LabelEncoder) Hazırlama ---
# LabelEncoder'ın TÜM olası etiketleri bilmesi için onu döngüden önce eğitiyoruz.
print("Adım 4: Etiket Kodlayıcı Hazırlanıyor...")
label_encoder = LabelEncoder()
label_encoder.fit(all_labels_flat)
num_classes = len(label_encoder.classes_)
print(f"Bulunan sınıflar ({num_classes} adet): {label_encoder.classes_}\n")


# --- Adım 5: Leave-One-User-Out Çapraz Doğrulama (LOUOCV) Döngüsü ---
print("Adım 5: LOUOCV Başlatılıyor...")

all_scores = []
all_reports = {}

# Her bir kullanıcıyı sırayla test seti olarak ayır
for user_to_test in USERS_TO_ANALYZE:
    print(f"-------------------------------------------------")
    print(f"TEST KULLANICISI: {user_to_test}")
    print(f"-------------------------------------------------")
    
    # 1. Eğitim ve Test Verisini Ayır
    X_train_raw = []
    y_train_raw = []
    
    # Test verisi, dışarıda bırakılan kullanıcıdır
    X_test_raw = data_by_user[user_to_test]['data']
    y_test_raw = data_by_user[user_to_test]['labels']
    
    # Geri kalan tüm kullanıcılar eğitim verisidir
    for user_to_train in USERS_TO_ANALYZE:
        if user_to_train == user_to_test:
            continue # Test kullanıcısını atla
        X_train_raw.extend(data_by_user[user_to_train]['data'])
        y_train_raw.extend(data_by_user[user_to_train]['labels'])
        
    # 2. Boyut Eşitleme (Padding/Trimming)
    X_train = pad_sequences(X_train_raw, maxlen=TIMESTEPS, dtype='float32', padding='post', truncating='post')
    X_test = pad_sequences(X_test_raw, maxlen=TIMESTEPS, dtype='float32', padding='post', truncating='post')
    
    # 3. Etiketleri Kodlama (fit etmeden, sadece transform)
    y_train_encoded = label_encoder.transform(y_train_raw)
    y_test_encoded = label_encoder.transform(y_test_raw)
    
    y_train = to_categorical(y_train_encoded, num_classes=num_classes)
    y_test = to_categorical(y_test_encoded, num_classes=num_classes)

    # 4. Ölçekleme (Scaler'ı SADECE EĞİTİM VERİSİNE GÖRE EĞİT)
    scaler = StandardScaler()
    X_train_reshaped = X_train.reshape(-1, FEATURES)
    scaler.fit(X_train_reshaped) # Sadece eğitim verisine fit et
    
    X_train_scaled = scaler.transform(X_train_reshaped).reshape(X_train.shape)
    X_test_scaled = scaler.transform(X_test.reshape(-1, FEATURES)).reshape(X_test.shape)

    # 5. Modeli Oluştur ve Eğit
    print(f"{user_to_test} dışarıda, {len(X_train)} kayıt ile model eğitiliyor...")
    model = build_model(num_classes)
    
    history = model.fit(
        X_train_scaled, 
        y_train, 
        epochs=60, 
        batch_size=16, 
        validation_data=(X_test_scaled, y_test), # Test kullanıcısını validasyon olarak kullan
        verbose=0 # (Eğitim loglarını gizle, sadece sonu gör)
    )
    
    # 6. Modeli Değerlendir
    loss, accuracy = model.evaluate(X_test_scaled, y_test, verbose=0)
    all_scores.append(accuracy)
    
    y_pred_probs = model.predict(X_test_scaled)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_test_labels = np.argmax(y_test, axis=1)
    
    print(f"\n{user_to_test} Test Sonuçları (Accuracy: {accuracy*100:.2f}%):")
    report = classification_report(y_test_labels, y_pred, target_names=label_encoder.classes_)
    print(report)
    all_reports[user_to_test] = report

print("\n\n--- LOUOCV GENEL SONUÇLARI ---")
for i, user in enumerate(USERS_TO_ANALYZE):
    print(f"{user} Test Doğruluğu: {all_scores[i] * 100:.2f}%")

print(f"\nOrtalama Test Doğruluğu (Genelleme Yeteneği): {np.mean(all_scores) * 100:.2f}%")
# Out:
# Adım 3: Veri Kullanıcılara Göre Yükleniyor...
# Kullanıcı yükleniyor: User-A
# Kullanıcı yükleniyor: User-B
# Kullanıcı yükleniyor: User-C
# Kullanıcı yükleniyor: User-D
# Kullanıcı yükleniyor: User-E
# Veri Yükleme Tamamlandı.
#
# Adım 4: Etiket Kodlayıcı Hazırlanıyor...
# Bulunan sınıflar (4 adet): ['LeaningOppositeSide' 'TooHighAbduction' 'True' 'WrongElbow']
#
# Adım 5: LOUOCV Başlatılıyor...
# -------------------------------------------------
# TEST KULLANICISI: User-A
# -------------------------------------------------
# User-A dışarıda, 240 kayıt ile model eğitiliyor...
# /opt/conda/envs/python313/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f37b45f8ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f37b45f8ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/stepWARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f37b45f8ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f37b45f8ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 373ms/step
#
# User-A Test Sonuçları (Accuracy: 63.33%):
#                      precision    recall  f1-score   support
#
# LeaningOppositeSide       0.00      0.00      0.00        15
#    TooHighAbduction       0.56      1.00      0.71        15
#                True       0.89      0.53      0.67        15
#          WrongElbow       0.62      1.00      0.77        15
#
#            accuracy                           0.63        60
#           macro avg       0.52      0.63      0.54        60
#        weighted avg       0.52      0.63      0.54        60
#
# -------------------------------------------------
# TEST KULLANICISI: User-B
# -------------------------------------------------
# User-B dışarıda, 240 kayıt ile model eğitiliyor...
# /opt/conda/envs/python313/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/envs/python313/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/envs/python313/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/envs/python313/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 384ms/step
#
# User-B Test Sonuçları (Accuracy: 61.67%):
#                      precision    recall  f1-score   support
#
# LeaningOppositeSide       1.00      0.47      0.64        15
#    TooHighAbduction       0.00      0.00      0.00        15
#                True       0.39      1.00      0.57        15
#          WrongElbow       1.00      1.00      1.00        15
#
#            accuracy                           0.62        60
#           macro avg       0.60      0.62      0.55        60
#        weighted avg       0.60      0.62      0.55        60
#
# -------------------------------------------------
# TEST KULLANICISI: User-C
# -------------------------------------------------
# User-C dışarıda, 240 kayıt ile model eğitiliyor...
# /opt/conda/envs/python313/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/envs/python313/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/envs/python313/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/envs/python313/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 388ms/step
#
# User-C Test Sonuçları (Accuracy: 60.00%):
#                      precision    recall  f1-score   support
#
# LeaningOppositeSide       0.00      0.00      0.00        15
#    TooHighAbduction       0.67      0.40      0.50        15
#                True       0.42      1.00      0.59        15
#          WrongElbow       1.00      1.00      1.00        15
#
#            accuracy                           0.60        60
#           macro avg       0.52      0.60      0.52        60
#        weighted avg       0.52      0.60      0.52        60
#
# -------------------------------------------------
# TEST KULLANICISI: User-D
# -------------------------------------------------
# User-D dışarıda, 240 kayıt ile model eğitiliyor...
# /opt/conda/envs/python313/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/envs/python313/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/envs/python313/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/envs/python313/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 377ms/step
#
# User-D Test Sonuçları (Accuracy: 55.00%):
#                      precision    recall  f1-score   support
#
# LeaningOppositeSide       0.25      0.33      0.29        15
#    TooHighAbduction       0.50      0.07      0.12        15
#                True       0.93      0.87      0.90        15
#          WrongElbow       0.58      0.93      0.72        15
#
#            accuracy                           0.55        60
#           macro avg       0.57      0.55      0.50        60
#        weighted avg       0.57      0.55      0.50        60
#
# -------------------------------------------------
# TEST KULLANICISI: User-E
# -------------------------------------------------
# User-E dışarıda, 240 kayıt ile model eğitiliyor...
# /opt/conda/envs/python313/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step
#
# User-E Test Sonuçları (Accuracy: 41.67%):
#                      precision    recall  f1-score   support
#
# LeaningOppositeSide       0.23      0.33      0.27        15
#    TooHighAbduction       0.47      0.47      0.47        15
#                True       0.50      0.13      0.21        15
#          WrongElbow       0.58      0.73      0.65        15
#
#            accuracy                           0.42        60
#           macro avg       0.44      0.42      0.40        60
#        weighted avg       0.44      0.42      0.40        60
#
#
#
# --- LOUOCV GENEL SONUÇLARI ---
# User-A Test Doğruluğu: 63.33%
# User-B Test Doğruluğu: 61.67%
# User-C Test Doğruluğu: 60.00%
# User-D Test Doğruluğu: 55.00%
# User-E Test Doğruluğu: 41.67%
#
# Ortalama Test Doğruluğu (Genelleme Yeteneği): 56.33%

# %%
# Adım 1: Gerekli Kütüphaneleri Yükleme
import os
import numpy as np
import pickle
import copy # Scaler'ı kopyalamak için
from pyquaternion import Quaternion # Normalizasyon için
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# TensorFlow ve Keras kütüphanelerini import etme
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    LSTM, GRU, Conv1D, MaxPooling1D, GlobalAveragePooling1D,
    Dense, Dropout, BatchNormalization, Input, LayerNormalization, 
    MultiHeadAttention, Add
)
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Flatten # <-- Ekle


# GPU hatalarını ve gereksiz uyarıları gizle
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')

# --- KONFİGÜRASYON ---
DATA_FOLDER = '' 
MOVEMENT_TYPE = '' # Test etmek istediğin hareket
TIMESTEPS = 80 # Veri setindeki (80, 40) şekline göre
NUM_SENSORS = 10
FEATURES_PER_SENSOR = 4 # w, x, y, z
FEATURES = NUM_SENSORS * FEATURES_PER_SENSOR
USERS_TO_ANALYZE = ["User-A", "User-B", "User-C", "User-D", "User-E"]

# Eğitim Ayarları
EPOCHS = 100 # Overfitting'i önlemek için EarlyStopping kullanacağız
BATCH_SIZE = 16

# --- Adım 2: Yardımcı Fonksiyonlar (Veri İşleme) ---

def normalize_sequence(sequence_data):
    """
    (N, 40) şeklindeki bir NumPy dizisini ilk karesine göre normalize eder.
    (w, x, y, z) sırasına göre.
    """
    if not sequence_data.any(): return sequence_data
    first_frame = sequence_data[0]
    inverse_references = []
    for i in range(NUM_SENSORS):
        offset = i * FEATURES_PER_SENSOR
        w, x, y, z = first_frame[offset:offset+4]
        q_ref = Quaternion(w, x, y, z) if (w or x or y or z) else Quaternion(1, 0, 0, 0)
        inverse_references.append(q_ref.inverse)
        
    normalized_sequence = []
    for frame in sequence_data:
        normalized_frame_features = []
        for i in range(NUM_SENSORS):
            offset = i * FEATURES_PER_SENSOR
            w, x, y, z = frame[offset:offset+4]
            q_live = Quaternion(w, x, y, z) if (w or x or y or z) else Quaternion(1, 0, 0, 0)
            q_normalized = inverse_references[i] * q_live
            normalized_frame_features.extend([q_normalized.w, q_normalized.x, q_normalized.y, q_normalized.z])
        normalized_sequence.append(normalized_frame_features)
    return np.array(normalized_sequence)

def augment_data(sequence_data, noise_level=0.01):
    """Veriye rastgele küçük gürültüler (jitter) ekler."""
    noise = np.random.normal(0, noise_level, sequence_data.shape)
    return sequence_data + noise

# --- Adım 3: Model Mimarilerini Oluşturan Fonksiyonlar ---

INPUT_SHAPE = (TIMESTEPS, FEATURES)

def build_cnn_lstm_model(num_classes):
    """Senin başarılı CNN-LSTM Hibrid modelin."""
    model = Sequential([
        Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=INPUT_SHAPE),
        Conv1D(filters=64, kernel_size=3, activation='relu'),
        MaxPooling1D(pool_size=2),
        BatchNormalization(),
        Dropout(0.3),
        LSTM(50, return_sequences=False),
        BatchNormalization(),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dense(num_classes, activation='softmax')
    ], name="CNN_LSTM")
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model


def build_cnn_ann_model(num_classes):
    model = Sequential([
        Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=INPUT_SHAPE),
        MaxPooling1D(pool_size=2),
        BatchNormalization(),
        Dropout(0.3),
        
        Conv1D(filters=128, kernel_size=3, activation='relu'),
        MaxPooling1D(pool_size=2),
        BatchNormalization(),
        Dropout(0.3),
        
        Flatten(), # <-- GlobalAveragePooling yerine Flatten
        
        Dense(100, activation='relu'),
        Dropout(0.4),
        Dense(num_classes, activation='softmax')
    ], name="CNN_ANN_Hybrid")
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def build_pure_cnn_model(num_classes):
    """Sadece 1D-CNN katmanları kullanan model."""
    model = Sequential([
        Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=INPUT_SHAPE),
        BatchNormalization(),
        Conv1D(filters=64, kernel_size=3, activation='relu'),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(0.3),
        
        Conv1D(filters=128, kernel_size=3, activation='relu'),
        BatchNormalization(),
        Conv1D(filters=128, kernel_size=3, activation='relu'),
        BatchNormalization(),
        GlobalAveragePooling1D(), # <-- LSTM/GRU yerine
        
        Dropout(0.4),
        Dense(64, activation='relu'),
        Dense(num_classes, activation='softmax')
    ], name="Pure_1D_CNN")
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def build_transformer_model(num_classes):
    """Basit bir Transformer Encoder bloğu kullanan model."""
    inputs = Input(shape=INPUT_SHAPE)
    
    # 1. Önce CNN ile özellikleri çıkaralım (Transformer'a yardımcı olur)
    x = Conv1D(filters=64, kernel_size=3, activation='relu')(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    # --- Transformer Encoder Bloğu ---
    # 2. Multi-Head Attention
    attn_output = MultiHeadAttention(num_heads=4, key_dim=64)(x, x)
    attn_output = Dropout(0.2)(attn_output)
    x = Add()([x, attn_output]) # Residual Connection (Toplama)
    x = LayerNormalization(epsilon=1e-6)(x)
    
    # 3. Feed Forward Kısmı
    ff_output = Dense(128, activation='relu')(x)
    ff_output = Dropout(0.2)(ff_output)
    ff_output = Dense(64, activation='relu')(ff_output)
    x = Add()([x, ff_output]) # Residual Connection
    x = LayerNormalization(epsilon=1e-6)(x)
    # --- Blok Sonu ---
    
    x = GlobalAveragePooling1D()(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=inputs, outputs=outputs, name="Transformer")
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model


# --- Adım 4: Veriyi Yükleme ve Ön İşleme ---
print("Adım 4: Veri Yükleme ve Ön İşleme Başladı...")
data_by_user = {}
all_labels_flat = []

movement_path = os.path.join(DATA_FOLDER, MOVEMENT_TYPE)
for user_folder in USERS_TO_ANALYZE:
    user_path = os.path.join(movement_path, user_folder)
    if not os.path.isdir(user_path):
        print(f"Uyarı: Kullanıcı klasörü atlanıyor (bulunamadı): {user_path}")
        continue
    
    print(f"Kullanıcı yükleniyor: {user_folder}")
    data_by_user[user_folder] = {'data': [], 'labels': []}
    
    for label_folder in os.listdir(user_path):
        label_path = os.path.join(user_path, label_folder)
        if os.path.isdir(label_path):
            for pkl_file in os.listdir(label_path):
                if pkl_file.endswith('.pkl'):
                    file_path = os.path.join(label_path, pkl_file)
                    try:
                        with open(file_path, 'rb') as f:
                            obj = pickle.load(f)
                        recording_data = np.array(obj['data'])
                        if recording_data.shape[0] < 1 or recording_data.shape[1] != FEATURES:
                            continue
                        
                        # --- Normalizasyon ve Boyut Eşitleme ---
                        recording_data_normalized = normalize_sequence(recording_data)
                        recording_data_padded = pad_sequences(
                            [recording_data_normalized], maxlen=TIMESTEPS, dtype='float32', 
                            padding='post', truncating='post'
                        )[0] # [0] ile (1, 80, 40) yerine (80, 40) al
                        
                        data_by_user[user_folder]['data'].append(recording_data_padded)
                        data_by_user[user_folder]['labels'].append(label_folder)
                        all_labels_flat.append(label_folder)
                    except Exception as e:
                        print(f"Hata: {file_path} dosyası okunurken hata oluştu: {e}")

print("Veri Yükleme Tamamlandı.\n")

# --- Adım 5: Etiket Kodlayıcıyı Hazırlama ---
label_encoder = LabelEncoder()
label_encoder.fit(all_labels_flat)
num_classes = len(label_encoder.classes_)
print(f"Bulunan sınıflar ({num_classes} adet): {label_encoder.classes_}\n")

# --- Adım 6: LOUOCV Test Çatısı ---
print("Adım 6: LOUOCV Test Çatısı Başlatılıyor...")

# Test edilecek modelleri ve oluşturma fonksiyonlarını bir sözlükte topla
models_to_test = {
    #"CNN-LSTM": build_cnn_lstm_model,
    #"Pure 1D-CNN": build_pure_cnn_model,
    "Transformer": build_transformer_model,
    #"ANN": build_cnn_ann_model
}

# Sonuçları saklamak için
overall_results = {}
all_classification_reports = {}

# Aşırı öğrenmeyi engellemek için Erken Durdurma
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Her bir model için döngü
for model_name, build_fn in models_to_test.items():
    print(f"\n==============================================")
    print(f"MODEL TEST EDİLİYOR: {model_name}")
    print(f"==============================================")
    
    fold_scores = []
    
    # LOUOCV döngüsü (her kullanıcı için)
    for user_to_test in USERS_TO_ANALYZE:
        print(f"\n--- Test Kullanıcısı: {user_to_test} ---")
        
        # 1. Eğitim ve Test Verisini Ayır
        X_train_list, y_train_list = [], []
        X_test_list, y_test_list = [], []

        for user, data in data_by_user.items():
            if user == user_to_test:
                X_test_list.extend(data['data'])
                y_test_list.extend(data['labels'])
            else:
                X_train_list.extend(data['data'])
                y_train_list.extend(data['labels'])

        # 2. Veri Artırma (Sadece Eğitim Verisine)
        X_train_aug, y_train_aug = [], []
        for i in range(len(X_train_list)):
            seq, lbl = X_train_list[i], y_train_list[i]
            X_train_aug.append(seq) # Orijinal
            y_train_aug.append(lbl)
            X_train_aug.append(augment_data(seq, 0.01)) # Gürültülü 1
            y_train_aug.append(lbl)
            X_train_aug.append(augment_data(seq, 0.005)) # Gürültülü 2
            y_train_aug.append(lbl)

        X_train = np.array(X_train_aug)
        X_test = np.array(X_test_list)
        
        # 3. Etiketleri Kodla
        y_train = to_categorical(label_encoder.transform(y_train_aug), num_classes=num_classes)
        y_test = to_categorical(label_encoder.transform(y_test_list), num_classes=num_classes)

        # 4. Ölçekle (Scaler'ı SADECE artırılmış eğitim verisine göre eğit)
        scaler = StandardScaler()
        X_train_reshaped = X_train.reshape(-1, FEATURES)
        scaler.fit(X_train_reshaped)
        
        X_train_scaled = scaler.transform(X_train_reshaped).reshape(X_train.shape)
        X_test_scaled = scaler.transform(X_test.reshape(-1, FEATURES)).reshape(X_test.shape)
        
        print(f"Eğitim verisi: {X_train_scaled.shape}, Test verisi: {X_test_scaled.shape}")

        # 5. Modeli Oluştur ve Eğit
        model = build_fn(num_classes)
        model.fit(
            X_train_scaled, y_train,
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            validation_data=(X_test_scaled, y_test),
            callbacks=[early_stopping], # Erken durdurmayı kullan
            verbose=0 # Logları gizle
        )
        
        # 6. Değerlendir
        loss, accuracy = model.evaluate(X_test_scaled, y_test, verbose=0)
        fold_scores.append(accuracy)
        print(f"{user_to_test} için Doğruluk: {accuracy * 100:.2f}%")

    # Modelin ortalama LOUOCV skorunu kaydet
    overall_results[model_name] = np.mean(fold_scores)


# --- Adım 7: Nihai Sonuçları Göster ---
print("\n\n==============================================")
print("     LOUOCV GENEL SONUÇLARI     ")
print("==============================================")
print(f"Test Edilen Hareket: {MOVEMENT_TYPE}")
print(f"Veri Seti: {len(USERS_TO_ANALYZE)} Kullanıcı, Toplam {len(all_labels_flat)} Orijinal Kayıt")
print("----------------------------------------------")

for model_name, avg_accuracy in overall_results.items():
    print(f"Model: {model_name.ljust(12)} | Ortalama Genelleme Doğruluğu: {avg_accuracy * 100:.2f}%")

print("==============================================")
# Out:
# Adım 4: Veri Yükleme ve Ön İşleme Başladı...
# Kullanıcı yükleniyor: User-A
# Kullanıcı yükleniyor: User-B
# Kullanıcı yükleniyor: User-C
# Kullanıcı yükleniyor: User-D
# Kullanıcı yükleniyor: User-E
# Veri Yükleme Tamamlandı.
#
# Bulunan sınıflar (4 adet): ['LeaningOppositeSide' 'TooHighAbduction' 'True' 'WrongElbow']
#
# Adım 6: LOUOCV Test Çatısı Başlatılıyor...
#
# ==============================================
# MODEL TEST EDİLİYOR: CNN-LSTM
# ==============================================
#
# --- Test Kullanıcısı: User-A ---
# Eğitim verisi: (720, 80, 40), Test verisi: (60, 80, 40)
# User-A için Doğruluk: 85.00%
#
# --- Test Kullanıcısı: User-B ---
# Eğitim verisi: (720, 80, 40), Test verisi: (60, 80, 40)
# User-B için Doğruluk: 51.67%
#
# --- Test Kullanıcısı: User-C ---
# Eğitim verisi: (720, 80, 40), Test verisi: (60, 80, 40)
# User-C için Doğruluk: 36.67%
#
# --- Test Kullanıcısı: User-D ---
# Eğitim verisi: (720, 80, 40), Test verisi: (60, 80, 40)
# User-D için Doğruluk: 81.67%
#
# --- Test Kullanıcısı: User-E ---
# Eğitim verisi: (720, 80, 40), Test verisi: (60, 80, 40)
# User-E için Doğruluk: 50.00%
#
#
# ==============================================
#      LOUOCV GENEL SONUÇLARI
# ==============================================
# Test Edilen Hareket:
# Veri Seti: 5 Kullanıcı, Toplam 300 Orijinal Kayıt
# ----------------------------------------------
# Model: CNN-LSTM     | Ortalama Genelleme Doğruluğu: 61.00%
# ==============================================

# %%
# Adım 1: Gerekli Kütüphaneleri Yükleme
import os
import numpy as np
import pickle
from pyquaternion import Quaternion
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    LSTM, GRU, Conv1D, MaxPooling1D, GlobalAveragePooling1D,
    Dense, Dropout, BatchNormalization, Input, LayerNormalization, 
    MultiHeadAttention, Add
)
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import classification_report, accuracy_score
from tensorflow.keras.callbacks import EarlyStopping
import warnings
from tensorflow.keras.layers import Flatten # <-- Ekle
# Gereksiz TensorFlow ve Keras uyarılarını gizle
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 
tf.get_logger().setLevel('ERROR')
warnings.filterwarnings('ignore', category=UserWarning) # Keras uyarılarını gizle

# --- KONFİGÜRASYON ---
DATA_FOLDER = '' 
MOVEMENT_TYPE = ''
TIMESTEPS = 80
NUM_SENSORS = 10
FEATURES_PER_SENSOR = 4 # w, x, y, z
FEATURES = NUM_SENSORS * FEATURES_PER_SENSOR
USERS_TO_ANALYZE = ["User-A", "User-B", "User-C", "User-D", "User-E"]
EPOCHS = 60
BATCH_SIZE = 16

# --- Adım 2: Yardımcı Fonksiyonlar ---

def normalize_sequence(sequence_data):
    """(N, 40) veriyi ilk karesine göre normalize eder."""
    if not sequence_data.any(): return sequence_data
    first_frame = sequence_data[0]
    inverse_references = []
    for i in range(NUM_SENSORS):
        offset = i * FEATURES_PER_SENSOR
        w, x, y, z = first_frame[offset:offset+4]
        q_ref = Quaternion(w, x, y, z) if (w or x or y or z) else Quaternion(1, 0, 0, 0)
        inverse_references.append(q_ref.inverse)
        
    normalized_sequence = []
    for frame in sequence_data:
        normalized_frame_features = []
        for i in range(NUM_SENSORS):
            offset = i * FEATURES_PER_SENSOR
            w, x, y, z = frame[offset:offset+4]
            q_live = Quaternion(w, x, y, z) if (w or x or y or z) else Quaternion(1, 0, 0, 0)
            q_normalized = inverse_references[i] * q_live
            normalized_frame_features.extend([q_normalized.w, q_normalized.x, q_normalized.y, q_normalized.z])
        normalized_sequence.append(normalized_frame_features)
    return np.array(normalized_sequence)

# --- Adım 3: Model Mimarilerini Oluşturan Fonksiyonlar ---
INPUT_SHAPE = (TIMESTEPS, FEATURES)

def build_cnn_lstm_model(num_classes):
    model = Sequential([
        Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=INPUT_SHAPE),
        Conv1D(filters=64, kernel_size=3, activation='relu'),
        MaxPooling1D(pool_size=2),
        BatchNormalization(),
        Dropout(0.3),
        LSTM(50, return_sequences=False),
        BatchNormalization(),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dense(num_classes, activation='softmax')
    ], name="CNN_LSTM")
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def build_cnn_ann_model(num_classes):
    model = Sequential([
        Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=INPUT_SHAPE),
        MaxPooling1D(pool_size=2),
        BatchNormalization(),
        Dropout(0.3),
        
        Conv1D(filters=128, kernel_size=3, activation='relu'),
        MaxPooling1D(pool_size=2),
        BatchNormalization(),
        Dropout(0.3),
        
        Flatten(), # <-- GlobalAveragePooling yerine Flatten
        
        Dense(100, activation='relu'),
        Dropout(0.4),
        Dense(num_classes, activation='softmax')
    ], name="CNN_ANN_Hybrid")
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model
def build_pure_cnn_model(num_classes):
    model = Sequential([
        Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=INPUT_SHAPE),
        BatchNormalization(),
        Conv1D(filters=64, kernel_size=3, activation='relu'),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(0.3),
        Conv1D(filters=128, kernel_size=3, activation='relu'),
        BatchNormalization(),
        Conv1D(filters=128, kernel_size=3, activation='relu'),
        BatchNormalization(),
        GlobalAveragePooling1D(),
        Dropout(0.4),
        Dense(64, activation='relu'),
        Dense(num_classes, activation='softmax')
    ], name="Pure_1D_CNN")
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def build_transformer_model(num_classes):
    inputs = Input(shape=INPUT_SHAPE)
    x = Conv1D(filters=64, kernel_size=3, activation='relu')(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    attn_output = MultiHeadAttention(num_heads=4, key_dim=64)(x, x)
    attn_output = Dropout(0.2)(attn_output)
    x = Add()([x, attn_output])
    x = LayerNormalization(epsilon=1e-6)(x)
    
    ff_output = Dense(128, activation='relu')(x)
    ff_output = Dropout(0.2)(ff_output)
    ff_output = Dense(64, activation='relu')(ff_output)
    x = Add()([x, ff_output])
    x = LayerNormalization(epsilon=1e-6)(x)
    
    x = GlobalAveragePooling1D()(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=inputs, outputs=outputs, name="Transformer")
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# --- Adım 4: Veriyi Yükleme, İşleme ve Ayırma ---
print("Adım 4: Veri Yükleniyor ve İşleniyor...")

all_data = []
all_labels = []
movement_path = os.path.join(DATA_FOLDER, MOVEMENT_TYPE)

for user_folder in USERS_TO_ANALYZE:
    user_path = os.path.join(movement_path, user_folder)
    if not os.path.isdir(user_path): continue
    for label_folder in os.listdir(user_path):
        label_path = os.path.join(user_path, label_folder)
        if os.path.isdir(label_path):
            for pkl_file in os.listdir(label_path):
                if pkl_file.endswith('.pkl'):
                    file_path = os.path.join(label_path, pkl_file)
                    try:
                        with open(file_path, 'rb') as f: obj = pickle.load(f)
                        recording_data = np.array(obj['data'])
                        if recording_data.shape[0] < 1 or recording_data.shape[1] != FEATURES: continue
                        
                        recording_data_normalized = normalize_sequence(recording_data)
                        recording_data_padded = pad_sequences(
                            [recording_data_normalized], maxlen=TIMESTEPS, dtype='float32', 
                            padding='post', truncating='post'
                        )[0]
                        
                        all_data.append(recording_data_padded)
                        all_labels.append(label_folder)
                    except Exception as e:
                        print(f"Hata: {file_path} dosyası okunurken hata oluştu: {e}")

print(f"Toplam {len(all_data)} adet orijinal .pkl kaydı yüklendi.")

# Etiketleri Kodla
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(all_labels)
num_classes = len(label_encoder.classes_)
y_one_hot = to_categorical(y_encoded, num_classes=num_classes)
X = np.array(all_data)

print(f"Bulunan sınıflar: {label_encoder.classes_}")

# Veriyi Rastgele Ayır (LOUOCV OLMADAN)
X_train, X_test, y_train, y_test = train_test_split(
    X, y_one_hot, 
    test_size=0.2, # 300 kaydın %20'si = 60 test kaydı
    random_state=42, 
    stratify=y_one_hot # Sınıf dağılımını koru
)

# Ölçekle
scaler = StandardScaler()
X_train_reshaped = X_train.reshape(-1, FEATURES)
scaler.fit(X_train_reshaped)

X_train_scaled = scaler.transform(X_train_reshaped).reshape(X_train.shape)
X_test_scaled = scaler.transform(X_test.reshape(-1, FEATURES)).reshape(X_test.shape)

print(f"Eğitim verisi: {X_train_scaled.shape}, Test verisi: {X_test_scaled.shape}")
print("Veri Ayırma ve Ölçekleme Tamamlandı.\n")

# --- Adım 5: Modelleri Karşılaştırmalı Olarak Eğitme ve Değerlendirme ---
print("Adım 5: Karşılaştırmalı Model Testi Başlatılıyor...")

models_to_test = {
    "CNN-LSTM": build_cnn_lstm_model,
    "Pure 1D-CNN": build_pure_cnn_model,
    "Transformer": build_transformer_model,
    "ANN": build_cnn_ann_model
}

results = {}
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

for model_name, build_fn in models_to_test.items():
    print(f"\n--- Model Eğitiliyor: {model_name} ---")
    model = build_fn(num_classes)
    
    model.fit(
        X_train_scaled, y_train,
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        validation_data=(X_test_scaled, y_test),
        callbacks=[early_stopping],
        verbose=0 # Logları gizle
    )
    
    # Değerlendir
    loss, accuracy = model.evaluate(X_test_scaled, y_test, verbose=0)
    print(f"Test Doğruluğu: {accuracy * 100:.2f}%")
    
    y_pred_probs = model.predict(X_test_scaled)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_test_labels = np.argmax(y_test, axis=1)
    
    print("Classification Report:")
    print(classification_report(y_test_labels, y_pred, target_names=label_encoder.classes_))
    
    results[model_name] = accuracy

# --- Adım 6: Nihai Sonuçları Göster ---
print("\n\n==============================================")
print("     RASTGELE BÖLME (Mixed-User) TEST SONUÇLARI     ")
print("==============================================")
print(f"Test Edilen Hareket: {MOVEMENT_TYPE}")
print(f"Veri Seti: {len(USERS_TO_ANALYZE)} Kullanıcı, Toplam {len(all_labels)} Orijinal Kayıt")
print("Veri Artırma: KULLANILMADI")
print("----------------------------------------------")

for model_name, avg_accuracy in results.items():
    print(f"Model: {model_name.ljust(12)} | Kişiselleştirilmiş Doğruluk: {avg_accuracy * 100:.2f}%")

print("==============================================")
# Out:
# Adım 4: Veri Yükleniyor ve İşleniyor...
# Toplam 300 adet orijinal .pkl kaydı yüklendi.
# Bulunan sınıflar: ['LeaningOppositeSide' 'TooHighAbduction' 'True' 'WrongElbow']
# Eğitim verisi: (240, 80, 40), Test verisi: (60, 80, 40)
# Veri Ayırma ve Ölçekleme Tamamlandı.
#
# Adım 5: Karşılaştırmalı Model Testi Başlatılıyor...
#
# --- Model Eğitiliyor: Transformer ---
# Test Doğruluğu: 98.33%
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# Classification Report:
#                      precision    recall  f1-score   support
#
# LeaningOppositeSide       1.00      0.93      0.97        15
#    TooHighAbduction       1.00      1.00      1.00        15
#                True       1.00      1.00      1.00        15
#          WrongElbow       0.94      1.00      0.97        15
#
#            accuracy                           0.98        60
#           macro avg       0.98      0.98      0.98        60
#        weighted avg       0.98      0.98      0.98        60
#
#
# --- Model Eğitiliyor: ANN ---
# Test Doğruluğu: 98.33%
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Classification Report:
#                      precision    recall  f1-score   support
#
# LeaningOppositeSide       1.00      0.93      0.97        15
#    TooHighAbduction       1.00      1.00      1.00        15
#                True       0.94      1.00      0.97        15
#          WrongElbow       1.00      1.00      1.00        15
#
#            accuracy                           0.98        60
#           macro avg       0.98      0.98      0.98        60
#        weighted avg       0.98      0.98      0.98        60
#
#
#
# ==============================================
#      RASTGELE BÖLME (Mixed-User) TEST SONUÇLARI
# ==============================================
# Test Edilen Hareket:
# Veri Seti: 5 Kullanıcı, Toplam 300 Orijinal Kayıt
# Veri Artırma: KULLANILMADI
# ----------------------------------------------
# Model: Transformer  | Kişiselleştirilmiş Doğruluk: 98.33%
# Model: ANN          | Kişiselleştirilmiş Doğruluk: 98.33%
# ==============================================

# %%
# Adım 1: Gerekli Kütüphaneleri Yükleme
import os
import numpy as np
import pickle
import copy 
from pyquaternion import Quaternion
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# TensorFlow ve Keras kütüphanelerini import etme
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    LSTM, Conv1D, MaxPooling1D, GlobalAveragePooling1D,
    Dense, Dropout, BatchNormalization, Input, LayerNormalization, 
    MultiHeadAttention, Add, Flatten
)
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping

# GPU hatalarını ve gereksiz uyarıları gizle
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')

# --- KONFİGÜRASYON ---
# LÜTFEN BUNLARI KENDİ VERİ YOLUNUZA GÖRE DÜZENLEYİN:
DATA_FOLDER = ''  
MOVEMENT_TYPE = '' # Test etmek istediğin hareket
TIMESTEPS = 80 # Veri setindeki (80, 40) şekline göre
NUM_SENSORS = 10
FEATURES_PER_SENSOR = 4 # w, x, y, z
FEATURES = NUM_SENSORS * FEATURES_PER_SENSOR
USERS_TO_ANALYZE = ["User-A", "User-B", "User-C", "User-D", "User-E"]

# Eğitim Ayarları
EPOCHS = 100
BATCH_SIZE = 16
INPUT_SHAPE = (TIMESTEPS, FEATURES)

# --- Adım 1.5: Görselleştirme Fonksiyonu ---

def plot_confusion_matrix(y_true_labels, y_pred_labels, class_names, title, save_path=None):
    """Confusion Matrix'i çizer ve kaydeder."""
    # Matrisi oluştur
    cm = confusion_matrix(y_true_labels, y_pred_labels)
    # Satır bazında normalize et (Her sınıfın ne kadar doğru tahmin edildiğini gösterir)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] 

    # Görselleştirme
    plt.figure(figsize=(8, 6))
    sns.heatmap(
        cm_normalized,
        annot=True,
        fmt=".2f", # 2 ondalık basamaklı format
        cmap="Blues",
        xticklabels=class_names,
        yticklabels=class_names
    )
    plt.title(f"Normalized Confusion Matrix: {title}")
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()

    if save_path:
        plt.savefig(save_path)
        print(f"Confusion Matrix {save_path} adresine kaydedildi.")
    plt.show()


# --- Adım 2: Yardımcı Fonksiyonlar (Veri İşleme) ---

def normalize_sequence(sequence_data):
    """
    (N, 40) şeklindeki bir NumPy dizisini ilk karesine göre normalize eder.
    (w, x, y, z) sırasına göre.
    """
    if not sequence_data.any(): return sequence_data
    first_frame = sequence_data[0]
    inverse_references = []
    for i in range(NUM_SENSORS):
        offset = i * FEATURES_PER_SENSOR
        w, x, y, z = first_frame[offset:offset+4]
        q_ref = Quaternion(w, x, y, z) if (w or x or y or z) else Quaternion(1, 0, 0, 0)
        inverse_references.append(q_ref.inverse)
        
    normalized_sequence = []
    for frame in sequence_data:
        normalized_frame_features = []
        for i in range(NUM_SENSORS):
            offset = i * FEATURES_PER_SENSOR
            w, x, y, z = frame[offset:offset+4]
            q_live = Quaternion(w, x, y, z) if (w or x or y or z) else Quaternion(1, 0, 0, 0)
            q_normalized = inverse_references[i] * q_live
            normalized_frame_features.extend([q_normalized.w, q_normalized.x, q_normalized.y, q_normalized.z])
        normalized_sequence.append(normalized_frame_features)
    return np.array(normalized_sequence)

def augment_data(sequence_data, noise_level=0.01):
    """Veriye rastgele küçük gürültüler (jitter) ekler."""
    noise = np.random.normal(0, noise_level, sequence_data.shape)
    return sequence_data + noise

# --- Adım 3: Model Mimarilerini Oluşturan Fonksiyonlar ---
# Sadece Transformer modelini bırakıyorum. Diğer modelleri isterseniz ekleyebilirsiniz.

def build_transformer_model(num_classes):
    """Basit bir Transformer Encoder bloğu kullanan model."""
    inputs = Input(shape=INPUT_SHAPE)
    
    # 1. Önce CNN ile özellikleri çıkaralım
    x = Conv1D(filters=64, kernel_size=3, activation='relu')(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    # --- Transformer Encoder Bloğu ---
    # 2. Multi-Head Attention
    attn_output = MultiHeadAttention(num_heads=4, key_dim=64)(x, x)
    attn_output = Dropout(0.2)(attn_output)
    x = Add()([x, attn_output])
    x = LayerNormalization(epsilon=1e-6)(x)
    
    # 3. Feed Forward Kısmı
    ff_output = Dense(128, activation='relu')(x)
    ff_output = Dropout(0.2)(ff_output)
    ff_output = Dense(64, activation='relu')(ff_output)
    x = Add()([x, ff_output])
    x = LayerNormalization(epsilon=1e-6)(x)
    # --- Blok Sonu ---
    
    x = GlobalAveragePooling1D()(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=inputs, outputs=outputs, name="Transformer")
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model


# --- Adım 4: Veriyi Yükleme ve Ön İşleme ---
print("Adım 4: Veri Yükleme ve Ön İşleme Başladı...")
data_by_user = {}
all_labels_flat = []

movement_path = os.path.join(DATA_FOLDER, MOVEMENT_TYPE)
if not os.path.isdir(movement_path):
    print(f"HATA: Hareket klasörü bulunamadı: {movement_path}")
    print("Lütfen DATA_FOLDER ve MOVEMENT_TYPE değişkenlerini kontrol edin.")
    exit()

for user_folder in USERS_TO_ANALYZE:
    user_path = os.path.join(movement_path, user_folder)
    if not os.path.isdir(user_path):
        print(f"Uyarı: Kullanıcı klasörü atlanıyor (bulunamadı): {user_path}")
        continue
    
    print(f"Kullanıcı yükleniyor: {user_folder}")
    data_by_user[user_folder] = {'data': [], 'labels': []}
    
    for label_folder in os.listdir(user_path):
        label_path = os.path.join(user_path, label_folder)
        if os.path.isdir(label_path):
            for pkl_file in os.listdir(label_path):
                if pkl_file.endswith('.pkl'):
                    file_path = os.path.join(label_path, pkl_file)
                    try:
                        with open(file_path, 'rb') as f:
                            obj = pickle.load(f)
                        recording_data = np.array(obj['data'])
                        if recording_data.shape[0] < 1 or recording_data.shape[1] != FEATURES:
                            continue
                        
                        # --- Normalizasyon ve Boyut Eşitleme ---
                        recording_data_normalized = normalize_sequence(recording_data)
                        recording_data_padded = pad_sequences(
                            [recording_data_normalized], maxlen=TIMESTEPS, dtype='float32', 
                            padding='post', truncating='post'
                        )[0]
                        
                        data_by_user[user_folder]['data'].append(recording_data_padded)
                        data_by_user[user_folder]['labels'].append(label_folder)
                        all_labels_flat.append(label_folder)
                    except Exception as e:
                        print(f"Hata: {file_path} dosyası okunurken hata oluştu: {e}")

print("Veri Yükleme Tamamlandı.\n")

# --- Adım 5: Etiket Kodlayıcıyı Hazırlama ---
label_encoder = LabelEncoder()
label_encoder.fit(all_labels_flat)
num_classes = len(label_encoder.classes_)
class_names = label_encoder.classes_
print(f"Bulunan sınıflar ({num_classes} adet): {class_names}\n")

# --- Adım 6: LOUOCV Test Çatısı ---
print("Adım 6: LOUOCV Test Çatısı Başlatılıyor...")

models_to_test = {
    "Transformer": build_transformer_model,
}

overall_results = {}
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Her bir model için döngü
for model_name, build_fn in models_to_test.items():
    print(f"\n==============================================")
    print(f"MODEL TEST EDİLİYOR: {model_name}")
    print(f"==============================================")
    
    fold_scores = []
    # Confusion Matrix için tahminleri ve gerçek etiketleri toplamak için
    all_y_test_true = []
    all_y_test_pred = []
    
    # LOUOCV döngüsü (her kullanıcı için)
    for user_to_test in USERS_TO_ANALYZE:
        print(f"\n--- Test Kullanıcısı: {user_to_test} ---")
        
        # 1. Eğitim ve Test Verisini Ayır
        X_train_list, y_train_list = [], []
        X_test_list, y_test_list = [], []

        for user, data in data_by_user.items():
            if user == user_to_test:
                X_test_list.extend(data['data'])
                y_test_list.extend(data['labels'])
            else:
                X_train_list.extend(data['data'])
                y_train_list.extend(data['labels'])

        # 2. Veri Artırma (Sadece Eğitim Verisine)
        X_train_aug, y_train_aug = [], []
        for i in range(len(X_train_list)):
            seq, lbl = X_train_list[i], y_train_list[i]
            X_train_aug.append(seq) # Orijinal
            y_train_aug.append(lbl)
            X_train_aug.append(augment_data(seq, 0.01)) # Gürültülü 1
            y_train_aug.append(lbl)
            X_train_aug.append(augment_data(seq, 0.005)) # Gürültülü 2
            y_train_aug.append(lbl)

        X_train = np.array(X_train_aug)
        X_test = np.array(X_test_list)
        
        # 3. Etiketleri Kodla
        y_train = to_categorical(label_encoder.transform(y_train_aug), num_classes=num_classes)
        y_test = to_categorical(label_encoder.transform(y_test_list), num_classes=num_classes)

        # 4. Ölçekle (Scaler'ı SADECE artırılmış eğitim verisine göre eğit)
        scaler = StandardScaler()
        X_train_reshaped = X_train.reshape(-1, FEATURES)
        scaler.fit(X_train_reshaped)
        
        X_train_scaled = scaler.transform(X_train_reshaped).reshape(X_train.shape)
        X_test_scaled = scaler.transform(X_test.reshape(-1, FEATURES)).reshape(X_test.shape)
        
        print(f"Eğitim verisi: {X_train_scaled.shape}, Test verisi: {X_test_scaled.shape}")

        # 5. Modeli Oluştur ve Eğit
        model = build_fn(num_classes)
        model.fit(
            X_train_scaled, y_train,
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            validation_data=(X_test_scaled, y_test),
            callbacks=[early_stopping],
            verbose=0
        )
        
        # 6. Değerlendir
        loss, accuracy = model.evaluate(X_test_scaled, y_test, verbose=0)
        fold_scores.append(accuracy)
        print(f"{user_to_test} için Doğruluk: {accuracy * 100:.2f}%")

        # --- TAHMİNLERİ TOPLAMA KISMI ---
        y_pred_proba = model.predict(X_test_scaled, verbose=0)
        y_pred_fold = np.argmax(y_pred_proba, axis=1) # Tahmin edilen sınıf indeksi
        y_true_fold = np.argmax(y_test, axis=1)      # Gerçek sınıf indeksi
        
        # Etiketleri metin formatına geri çevir
        y_true_labels = label_encoder.inverse_transform(y_true_fold)
        y_pred_labels = label_encoder.inverse_transform(y_pred_fold)

        all_y_test_true.extend(y_true_labels)
        all_y_test_pred.extend(y_pred_labels)
        
    # Modelin ortalama LOUOCV skorunu kaydet
    overall_results[model_name] = np.mean(fold_scores)

    # --- CONFUSION MATRIX ÇİZİMİ ---
    plot_confusion_matrix(
        y_true_labels=all_y_test_true,
        y_pred_labels=all_y_test_pred,
        class_names=class_names,
        title=f"{model_name} LOUOCV Generalization ({MOVEMENT_TYPE})",
        save_path=f"{MOVEMENT_TYPE}_{model_name}_CM.png"
    )

# --- Adım 7: Nihai Sonuçları Göster ---
print("\n\n==============================================")
print("     LOUOCV GENEL SONUÇLARI     ")
print("==============================================")
print(f"Test Edilen Hareket: {MOVEMENT_TYPE}")
print(f"Veri Seti: {len(USERS_TO_ANALYZE)} Kullanıcı, Toplam {len(all_labels_flat)} Orijinal Kayıt")
print("----------------------------------------------")

for model_name, avg_accuracy in overall_results.items():
    print(f"Model: {model_name.ljust(12)} | Ortalama Genelleme Doğruluğu: {avg_accuracy * 100:.2f}%")

print("==============================================")
# Out:
# 2025-11-10 06:21:58.640853: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-10 06:21:58.641258: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-10 06:21:58.711300: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-10 06:22:00.026656: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-10 06:22:00.028170: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# Adım 4: Veri Yükleme ve Ön İşleme Başladı...
# HATA: Hareket klasörü bulunamadı:
# Lütfen DATA_FOLDER ve MOVEMENT_TYPE değişkenlerini kontrol edin.
# Kullanıcı yükleniyor: User-A
# Kullanıcı yükleniyor: User-B
# Kullanıcı yükleniyor: User-C
# Kullanıcı yükleniyor: User-D
# Kullanıcı yükleniyor: User-E
# Veri Yükleme Tamamlandı.
#
# Bulunan sınıflar (4 adet): ['LeaningOppositeSide' 'TooHighAbduction' 'True' 'WrongElbow']
#
# Adım 6: LOUOCV Test Çatısı Başlatılıyor...
#
# ==============================================
# MODEL TEST EDİLİYOR: Transformer
# ==============================================
#
# --- Test Kullanıcısı: User-A ---
# Eğitim verisi: (720, 80, 40), Test verisi: (60, 80, 40)
# 2025-11-10 06:22:03.871268: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# User-A için Doğruluk: 80.00%
#
# --- Test Kullanıcısı: User-B ---
# Eğitim verisi: (720, 80, 40), Test verisi: (60, 80, 40)
# User-B için Doğruluk: 86.67%
#
# --- Test Kullanıcısı: User-C ---
# Eğitim verisi: (720, 80, 40), Test verisi: (60, 80, 40)
# User-C için Doğruluk: 63.33%
#
# --- Test Kullanıcısı: User-D ---
# Eğitim verisi: (720, 80, 40), Test verisi: (60, 80, 40)
# User-D için Doğruluk: 65.00%
#
# --- Test Kullanıcısı: User-E ---
# Eğitim verisi: (720, 80, 40), Test verisi: (60, 80, 40)
# User-E için Doğruluk: 75.00%
# Confusion Matrix _Transformer_CM.png adresine kaydedildi.
# ==============================================
#      LOUOCV GENEL SONUÇLARI
# ==============================================
# Test Edilen Hareket:
# Veri Seti: 5 Kullanıcı, Toplam 300 Orijinal Kayıt
# ----------------------------------------------
# Model: Transformer  | Ortalama Genelleme Doğruluğu: 74.00%
# ==============================================

# %%
# Adım 1: Gerekli Kütüphaneleri Yükleme (Mevcut kodunuzdan)
import os
import numpy as np
import pickle
import copy 
from pyquaternion import Quaternion
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# ... (TensorFlow ve Keras kütüphane importları) ...
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    LSTM, Conv1D, MaxPooling1D, GlobalAveragePooling1D,
    Dense, Dropout, BatchNormalization, Input, LayerNormalization, 
    MultiHeadAttention, Add, Flatten
)
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping

# GPU hatalarını ve gereksiz uyarıları gizle (Mevcut kodunuzdan)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')

# --- KONFİGÜRASYON --- (Mevcut kodunuzdan)
DATA_FOLDER = ''  
MOVEMENT_TYPE = '' # Örn: ShoulderAbduction
TIMESTEPS = 80 
NUM_SENSORS = 10
FEATURES_PER_SENSOR = 4 
FEATURES = NUM_SENSORS * FEATURES_PER_SENSOR
USERS_TO_ANALYZE = ["User-A", "User-B", "User-C", "User-D", "User-E"]

# Eğitim Ayarları (Mevcut kodunuzdan)
EPOCHS = 100
BATCH_SIZE = 16
INPUT_SHAPE = (TIMESTEPS, FEATURES)

# --- Adım 1.5: YENİ GÖRSELLEŞTİRME FONKSİYONU ---

def plot_confusion_matrix(y_true_labels, y_pred_labels, class_names, title, save_path=None):
    """Confusion Matrix'i çizer: Gri tonlama, ham sayılar, İngilizce etiketler."""
    
    # Matrisi ham sayılarla (raw counts) oluştur
    cm = confusion_matrix(y_true_labels, y_pred_labels, labels=class_names)
    
    # Görselleştirme
    plt.figure(figsize=(8, 6))
    sns.heatmap(
        cm, # Normalleştirilmemiş matris
        annot=True,
        fmt="d", # Sayıları tamsayı (decimal) formatında göster
        cmap="Greys", # Gri tonlama paleti
        xticklabels=class_names,
        yticklabels=class_names
    )
    plt.title(f"Confusion Matrix (Raw Counts) for {title}")
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()

    if save_path:
        # Dosya adı uygunsa CM'yi kaydedin (Örn: ShoulderAbduction_Transformer_CM.png)
        plt.savefig(save_path)
        print(f"Confusion Matrix {save_path} adresine kaydedildi.")
    plt.show()


# --- Adım 2: Yardımcı Fonksiyonlar (Veri İşleme) --- (Mevcut kodunuzdan)

def normalize_sequence(sequence_data):
    """
    (N, 40) şeklindeki bir NumPy dizisini ilk karesine göre normalize eder.
    (w, x, y, z) sırasına göre.
    """
    if not sequence_data.any(): return sequence_data
    first_frame = sequence_data[0]
    inverse_references = []
    # ... (Normalizasyon mantığı) ...
    for i in range(NUM_SENSORS):
        offset = i * FEATURES_PER_SENSOR
        w, x, y, z = first_frame[offset:offset+4]
        q_ref = Quaternion(w, x, y, z) if (w or x or y or z) else Quaternion(1, 0, 0, 0)
        inverse_references.append(q_ref.inverse)
        
    normalized_sequence = []
    for frame in sequence_data:
        normalized_frame_features = []
        for i in range(NUM_SENSORS):
            offset = i * FEATURES_PER_SENSOR
            w, x, y, z = frame[offset:offset+4]
            q_live = Quaternion(w, x, y, z) if (w or x or y or z) else Quaternion(1, 0, 0, 0)
            q_normalized = inverse_references[i] * q_live
            normalized_frame_features.extend([q_normalized.w, q_normalized.x, q_normalized.y, q_normalized.z])
        normalized_sequence.append(normalized_frame_features)
    return np.array(normalized_sequence)

def augment_data(sequence_data, noise_level=0.01):
    """Veriye rastgele küçük gürültüler (jitter) ekler."""
    noise = np.random.normal(0, noise_level, sequence_data.shape)
    return sequence_data + noise

# --- Adım 3: Model Mimarilerini Oluşturan Fonksiyonlar --- (Mevcut kodunuzdan)

def build_transformer_model(num_classes):
    """Basit bir Transformer Encoder bloğu kullanan model."""
    inputs = Input(shape=INPUT_SHAPE)
    # ... (Transformer model mimarisi) ...
    
    # 1. Önce CNN ile özellikleri çıkaralım
    x = Conv1D(filters=64, kernel_size=3, activation='relu')(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    # --- Transformer Encoder Bloğu ---
    # 2. Multi-Head Attention
    attn_output = MultiHeadAttention(num_heads=4, key_dim=64)(x, x)
    attn_output = Dropout(0.2)(attn_output)
    x = Add()([x, attn_output])
    x = LayerNormalization(epsilon=1e-6)(x)
    
    # 3. Feed Forward Kısmı
    ff_output = Dense(128, activation='relu')(x)
    ff_output = Dropout(0.2)(ff_output)
    ff_output = Dense(64, activation='relu')(ff_output)
    x = Add()([x, ff_output])
    x = LayerNormalization(epsilon=1e-6)(x)
    
    x = GlobalAveragePooling1D()(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=inputs, outputs=outputs, name="Transformer")
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model


# --- Adım 4, 5, 6, 7: Veri Yükleme, Etiketleme, LOUOCV ve Sonuç Gösterimi ---
# Bu kısımlar, Adım 1.5'teki yeni fonksiyonu kullanarak çalışacaktır.
# *******************************************************************
# DİKKAT: Kodun kalanını çalıştırabilmek için bu kısımlar değişmeden kalmalıdır.
# *******************************************************************

# --- Adım 4: Veriyi Yükleme ve Ön İşleme ---
print("Adım 4: Veri Yükleme ve Ön İşleme Başladı...")
data_by_user = {}
all_labels_flat = []

movement_path = os.path.join(DATA_FOLDER, MOVEMENT_TYPE)
if not os.path.isdir(movement_path):
    print(f"HATA: Hareket klasörü bulunamadı: {movement_path}")
    print("Lütfen DATA_FOLDER ve MOVEMENT_TYPE değişkenlerini kontrol edin.")
    exit()

for user_folder in USERS_TO_ANALYZE:
    user_path = os.path.join(movement_path, user_folder)
    if not os.path.isdir(user_path):
        print(f"Uyarı: Kullanıcı klasörü atlanıyor (bulunamadı): {user_path}")
        continue
    
    print(f"Kullanıcı yükleniyor: {user_folder}")
    data_by_user[user_folder] = {'data': [], 'labels': []}
    
    for label_folder in os.listdir(user_path):
        label_path = os.path.join(user_path, label_folder)
        if os.path.isdir(label_path):
            for pkl_file in os.listdir(label_path):
                if pkl_file.endswith('.pkl'):
                    file_path = os.path.join(label_path, pkl_file)
                    try:
                        with open(file_path, 'rb') as f:
                            obj = pickle.load(f)
                        recording_data = np.array(obj['data'])
                        if recording_data.shape[0] < 1 or recording_data.shape[1] != FEATURES:
                            continue
                        
                        # --- Normalizasyon ve Boyut Eşitleme ---
                        recording_data_normalized = normalize_sequence(recording_data)
                        recording_data_padded = pad_sequences(
                            [recording_data_normalized], maxlen=TIMESTEPS, dtype='float32', 
                            padding='post', truncating='post'
                        )[0]
                        
                        data_by_user[user_folder]['data'].append(recording_data_padded)
                        data_by_user[user_folder]['labels'].append(label_folder)
                        all_labels_flat.append(label_folder)
                    except Exception as e:
                        print(f"Hata: {file_path} dosyası okunurken hata oluştu: {e}")

print("Veri Yükleme Tamamlandı.\n")

# --- Adım 5: Etiket Kodlayıcıyı Hazırlama ---
label_encoder = LabelEncoder()
label_encoder.fit(all_labels_flat)
num_classes = len(label_encoder.classes_)
class_names = label_encoder.classes_
print(f"Bulunan sınıflar ({num_classes} adet): {class_names}\n")

# --- Adım 6: LOUOCV Test Çatısı ---
print("Adım 6: LOUOCV Test Çatısı Başlatılıyor...")

models_to_test = {
    "Transformer": build_transformer_model,
}

overall_results = {}
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Her bir model için döngü
for model_name, build_fn in models_to_test.items():
    print(f"\n==============================================")
    print(f"MODEL TEST EDİLİYOR: {model_name}")
    print(f"==============================================")
    
    fold_scores = []
    # Confusion Matrix için tahminleri ve gerçek etiketleri toplamak için
    all_y_test_true = []
    all_y_test_pred = []
    
    # LOUOCV döngüsü (her kullanıcı için)
    for user_to_test in USERS_TO_ANALYZE:
        print(f"\n--- Test Kullanıcısı: {user_to_test} ---")
        
        # 1. Eğitim ve Test Verisini Ayır
        X_train_list, y_train_list = [], []
        X_test_list, y_test_list = [], []

        for user, data in data_by_user.items():
            if user == user_to_test:
                X_test_list.extend(data['data'])
                y_test_list.extend(data['labels'])
            else:
                X_train_list.extend(data['data'])
                y_train_list.extend(data['labels'])

        # 2. Veri Artırma (Sadece Eğitim Verisine)
        X_train_aug, y_train_aug = [], []
        for i in range(len(X_train_list)):
            seq, lbl = X_train_list[i], y_train_list[i]
            X_train_aug.append(seq) # Orijinal
            y_train_aug.append(lbl)
            X_train_aug.append(augment_data(seq, 0.01)) # Gürültülü 1
            y_train_aug.append(lbl)
            X_train_aug.append(augment_data(seq, 0.005)) # Gürültülü 2
            y_train_aug.append(lbl)

        X_train = np.array(X_train_aug)
        X_test = np.array(X_test_list)
        
        # 3. Etiketleri Kodla
        y_train = to_categorical(label_encoder.transform(y_train_aug), num_classes=num_classes)
        y_test = to_categorical(label_encoder.transform(y_test_list), num_classes=num_classes)

        # 4. Ölçekle (Scaler'ı SADECE artırılmış eğitim verisine göre eğit)
        scaler = StandardScaler()
        X_train_reshaped = X_train.reshape(-1, FEATURES)
        scaler.fit(X_train_reshaped)
        
        X_train_scaled = scaler.transform(X_train_reshaped).reshape(X_train.shape)
        X_test_scaled = scaler.transform(X_test.reshape(-1, FEATURES)).reshape(X_test.shape)
        
        print(f"Eğitim verisi: {X_train_scaled.shape}, Test verisi: {X_test_scaled.shape}")

        # 5. Modeli Oluştur ve Eğit
        model = build_fn(num_classes)
        model.fit(
            X_train_scaled, y_train,
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            validation_data=(X_test_scaled, y_test),
            callbacks=[early_stopping],
            verbose=0
        )
        
        # 6. Değerlendir
        loss, accuracy = model.evaluate(X_test_scaled, y_test, verbose=0)
        fold_scores.append(accuracy)
        print(f"{user_to_test} için Doğruluk: {accuracy * 100:.2f}%")

        # --- TAHMİNLERİ TOPLAMA KISMI ---
        y_pred_proba = model.predict(X_test_scaled, verbose=0)
        y_pred_fold = np.argmax(y_pred_proba, axis=1) # Tahmin edilen sınıf indeksi
        y_true_fold = np.argmax(y_test, axis=1)      # Gerçek sınıf indeksi
        
        # Etiketleri metin formatına geri çevir
        y_true_labels = label_encoder.inverse_transform(y_true_fold)
        y_pred_labels = label_encoder.inverse_transform(y_pred_fold)

        all_y_test_true.extend(y_true_labels)
        all_y_test_pred.extend(y_pred_labels)
        
    # Modelin ortalama LOUOCV skorunu kaydet
    overall_results[model_name] = np.mean(fold_scores)

    # --- CONFUSION MATRIX ÇİZİMİ ---
    plot_confusion_matrix(
        y_true_labels=all_y_test_true,
        y_pred_labels=all_y_test_pred,
        class_names=class_names,
        title=f"{model_name} LOUOCV Generalization ({MOVEMENT_TYPE})",
        save_path=f"{MOVEMENT_TYPE}_{model_name}_CM.png"
    )

# --- Adım 7: Nihai Sonuçları Göster ---
print("\n\n==============================================")
print("     LOUOCV GENEL SONUÇLARI     ")
print("==============================================")
print(f"Test Edilen Hareket: {MOVEMENT_TYPE}")
print(f"Veri Seti: {len(USERS_TO_ANALYZE)} Kullanıcı, Toplam {len(all_labels_flat)} Orijinal Kayıt")
print("----------------------------------------------")

for model_name, avg_accuracy in overall_results.items():
    print(f"Model: {model_name.ljust(12)} | Ortalama Genelleme Doğruluğu: {avg_accuracy * 100:.2f}%")

print("==============================================")
# Out:
# 2025-11-10 08:14:14.217522: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-10 08:14:14.217917: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-10 08:14:14.285056: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-10 08:14:15.571339: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-10 08:14:15.572872: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# Adım 4: Veri Yükleme ve Ön İşleme Başladı...
# HATA: Hareket klasörü bulunamadı:
# Lütfen DATA_FOLDER ve MOVEMENT_TYPE değişkenlerini kontrol edin.
# Kullanıcı yükleniyor: User-A
# Kullanıcı yükleniyor: User-B
# Kullanıcı yükleniyor: User-C
# Kullanıcı yükleniyor: User-D
# Kullanıcı yükleniyor: User-E
